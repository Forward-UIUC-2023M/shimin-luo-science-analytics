# %%
import csv
import requests

author_url = 'https://dblp.org/search/author/api?q={}&format=json'
cnt_total = 0
cnt_find_name = 0
cnt_find_institution = 0
is_find_DBLP = []

# %%
with open('../week 1/faculty_dataset_week2/faculty.csv', 'r') as file:
    csv_reader = csv.reader(file)

    for row in csv_reader:
        author = row[0]
        institution = row[1]

        if author in is_find_DBLP:
            print("continue")
            continue

        print(author+" "+ institution)
        cnt_total = cnt_total + 1

        # set page value and request page from OpenAlex
        url = author_url.format(author)
        print(url)

        page_with_results = requests.get(url).json()

        # loop through partial list of results
        results = page_with_results['result']['hits']
        is_find_DBLP.append(author)
        if int(results['@total']) > 0:
            cnt_find_name = cnt_find_name + 1
        # flag = False
            res = results['hit'][0]['info']
            print(res)
            if 'notes' in res:
                if 'note' in res['notes']:
                    # if len(res['notes']['note']) > 0 and res['notes']['note'][0]['@type'] == 'affiliation':
                    cnt_find_institution = cnt_find_institution + 1

    print("totally find: " + str(cnt_total))
    print("find: " + str(cnt_find_name))
    print("faculty with affiliation: " + str(cnt_find_institution))
# Out:
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# Wayne B Hayes University of California--Irvine
# https://dblp.org/search/author/api?q=Wayne B Hayes&format=json
# {'author': 'Wayne B. Hayes', 'notes': {'note': [{'@type': 'affiliation', 'text': 'University of California, Irvine, Department of Computer Science, CA, USA'}, {'@type': 'affiliation', 'text': 'University of Toronto, Department of Computer Science, ON, Canada'}]}, 'url': 'https://dblp.org/pid/51/232'}
# Gillian R Hayes University of California--Irvine
# https://dblp.org/search/author/api?q=Gillian R Hayes&format=json
# {'author': 'Gillian R. Hayes', 'aliases': {'alias': 'Gillian Hayes 0002'}, 'notes': {'note': [{'@type': 'affiliation', 'text': 'University of California, Irvine, USA'}, {'@type': 'affiliation', 'text': 'Georgia Institute of Technology, Atlanta, USA'}]}, 'url': 'https://dblp.org/pid/h/GillianRHayes'}
# Daniel S. Hirschberg University of California--Irvine
# https://dblp.org/search/author/api?q=Daniel S. Hirschberg&format=json
# {'author': 'Daniel S. Hirschberg', 'notes': {'note': {'@type': 'affiliation', 'text': 'University of California, Irvine, USA'}}, 'url': 'https://dblp.org/pid/h/DanielSHirschberg'}
# Mustafa Ibrahim University of California--Irvine
# https://dblp.org/search/author/api?q=Mustafa Ibrahim&format=json
# {'author': 'Mustafa S. Ibrahim Alsumaidaie', 'url': 'https://dblp.org/pid/345/5107'}
# Alexander Ihler University of California--Irvine
# https://dblp.org/search/author/api?q=Alexander Ihler&format=json
# {'author': 'Alexander Ihler', 'aliases': {'alias': ['Alexander T. Ihler', 'Alex H. Ihler']}, 'notes': {'note': {'@type': 'affiliation', 'text': 'University of California, Irvine, Department of Computer Science'}}, 'url': 'https://dblp.org/pid/39/1313'}
# Mohsen Imani University of California--Irvine
# https://dblp.org/search/author/api?q=Mohsen Imani&format=json
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# D:\Software\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# D:\Software\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000187F5A628E0>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# D:\Software\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='dblp.org', port=443): Max retries exceeded with url: /search/author/api?q=Mohsen%20Imani&format=json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000187F5A628E0>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21080\2513417456.py in <module>
#      17         print(url)
#      18
# ---> 19         page_with_results = requests.get(url).json()
#      20
#      21         # loop through partial list of results
#
# D:\Software\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# D:\Software\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# D:\Software\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# D:\Software\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# D:\Software\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     563                 raise SSLError(e, request=request)
#     564
# --> 565             raise ConnectionError(e, request=request)
#     566
#     567         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='dblp.org', port=443): Max retries exceeded with url: /search/author/api?q=Mohsen%20Imani&format=json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000187F5A628E0>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))

# %%
print("totally find: " + str(cnt_total))
print("find: " + str(cnt_find_name))
print("faculty with affiliation: " + str(cnt_find_institution))
# Out:
# totally find: 1486
# find: 1366
# faculty with affiliation: 682
