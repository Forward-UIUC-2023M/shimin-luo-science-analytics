# %%
cnt_total = 0
cnt_find_name = 0
cnt_find_institution = 0
is_find_semantic = []

# %%
import csv
import requests

author_url_with_page = 'https://api.semanticscholar.org/graph/v1/author/search?query={}&fields=name,affiliations'

with open('../week 1/faculty_dataset_week2/faculty.csv', 'r') as file:
    csv_reader = csv.reader(file)


# output_file = "find_semantic_info.txt"
# with open(output_file, 'a') as file:
    for row in csv_reader:
        author = row[0]
        institution = row[1]

        if author in is_find_semantic:
            print("continue")
            continue

        print(author+" "+ institution)
        cnt_total = cnt_total + 1

        # set page value and request page from OpenAlex
        url = author_url_with_page.format(author)
        print(url)

        page_with_results = requests.get(url).json()

        # loop through partial list of results
        results = page_with_results['data']
        is_find_semantic.append(author)
        if len(results)>0:
            cnt_find_name = cnt_find_name + 1
        # flag = False
        for i,res in enumerate(results):
            if 'affiliations' in res:
                if len(res['affiliations']) > 0:
                    cnt_find_institution = cnt_find_institution + 1
                    break

    print("totally find: " + str(cnt_total))
    print("find: " + str(cnt_find_name))
    print("faculty with affiliation: " + str(cnt_find_institution))
# Out:
# Agouris,Peggy College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Agouris,Peggy&fields=name,affiliations
# Chaparro,Oscar College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Chaparro,Oscar&fields=name,affiliations
# Davis,Tim College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Davis,Tim&fields=name,affiliations
# Deverick,James College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Deverick,James&fields=name,affiliations
# Evtyushkin,Dmitry College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Evtyushkin,Dmitry&fields=name,affiliations
# Hu,Tianran College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Hu,Tianran&fields=name,affiliations
# Jog,Adwait College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Jog,Adwait&fields=name,affiliations
# Kemper,Peter College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Kemper,Peter&fields=name,affiliations
# Khargonkar,Arohi College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Khargonkar,Arohi&fields=name,affiliations
# Kumar,Pradeep College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Kumar,Pradeep&fields=name,affiliations
# Lewis,Robert Michael College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Lewis,Robert Michael&fields=name,affiliations
# Li,Qun College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Li,Qun&fields=name,affiliations
# Liu,Zhenming College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Liu,Zhenming&fields=name,affiliations
# Mao,Weizhen College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Mao,Weizhen&fields=name,affiliations
# Nadkarni,Adwait College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Nadkarni,Adwait&fields=name,affiliations
# Peers,Pieter College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Peers,Pieter&fields=name,affiliations
# Poshyvanyk,Denys College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Poshyvanyk,Denys&fields=name,affiliations
# Ren,Bin College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Ren,Bin&fields=name,affiliations
# Shenefiel,Chris College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Shenefiel,Chris&fields=name,affiliations
# Smirni,Evgenia College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Smirni,Evgenia&fields=name,affiliations
# Stathopoulos,Andreas College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Stathopoulos,Andreas&fields=name,affiliations
# Stefanidis,Anthony College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Stefanidis,Anthony&fields=name,affiliations
# Sun,Yifan College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Sun,Yifan&fields=name,affiliations
# Torczon,Virginia College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Torczon,Virginia&fields=name,affiliations
# White,Martin College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=White,Martin&fields=name,affiliations
# Willner,Dana College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Willner,Dana&fields=name,affiliations
# Zhou,Gang College of William Mary
# https://api.semanticscholar.org/graph/v1/author/search?query=Zhou,Gang&fields=name,affiliations
# Allen, James F. University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Allen, James F.&fields=name,affiliations
# Bai, Zhen University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Bai, Zhen&fields=name,affiliations
# Criswell, John University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Criswell, John&fields=name,affiliations
# Ding, Chen University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Ding, Chen&fields=name,affiliations
# Dwarkadas, Sandhya University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Dwarkadas, Sandhya&fields=name,affiliations
# Ferguson, George University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Ferguson, George&fields=name,affiliations
# Gildea, Daniel University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Gildea, Daniel&fields=name,affiliations
# Hemaspaandra, Lane A. University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Hemaspaandra, Lane A.&fields=name,affiliations
# Hoque, Ehsan University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Hoque, Ehsan&fields=name,affiliations
# Jacobs, Robert A. University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Jacobs, Robert A.&fields=name,affiliations
# Kautz, Henry University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Kautz, Henry&fields=name,affiliations
# Luo, Jiebo University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Luo, Jiebo&fields=name,affiliations
# Nargesian, Fatemeh University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Nargesian, Fatemeh&fields=name,affiliations
# Pai, Sreepathi University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Pai, Sreepathi&fields=name,affiliations
# Pawlicki, Thaddeus E. University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Pawlicki, Thaddeus E.&fields=name,affiliations
# Purtee, Adam University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Purtee, Adam&fields=name,affiliations
# Schubert, Lenhart K. University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Schubert, Lenhart K.&fields=name,affiliations
# Scott, Michael L. University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Scott, Michael L.&fields=name,affiliations
# Stefankovic, Daniel University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Stefankovic, Daniel&fields=name,affiliations
# Venkitasubramaniam, Muthuramakrishnan University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Venkitasubramaniam, Muthuramakrishnan&fields=name,affiliations
# Xu, Chenliang University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Xu, Chenliang&fields=name,affiliations
# Zhu, Yuhao University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Zhu, Yuhao&fields=name,affiliations
# Zhupa, Eustrat University of Rochester
# https://api.semanticscholar.org/graph/v1/author/search?query=Zhupa, Eustrat&fields=name,affiliations
# Eugene Agichtein Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Eugene Agichtein&fields=name,affiliations
# Dorian Arnold Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Dorian Arnold&fields=name,affiliations
# Imon Banerjee Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Imon Banerjee&fields=name,affiliations
# Manoj K. Bhasin Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Manoj K. Bhasin&fields=name,affiliations
# Shun Yan Cheung Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Shun Yan Cheung&fields=name,affiliations
# Jinho Choi Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jinho Choi&fields=name,affiliations
# Gari Clifford, D. Phil. Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Gari Clifford, D. Phil.&fields=name,affiliations
# Nosayba El-Sayed Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Nosayba El-Sayed&fields=name,affiliations
# Davide Fossati Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Davide Fossati&fields=name,affiliations
# Michelangelo Grigni Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Michelangelo Grigni&fields=name,affiliations
# Joyce Ho Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Joyce Ho&fields=name,affiliations
# Rishi Kamaleswaran Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Rishi Kamaleswaran&fields=name,affiliations
# Qiao Li Emory University
# https://api.semanticscholar.org/graph/v1/author/search?query=Qiao Li&fields=name,affiliations

# %%
print("totally find: " + str(cnt_total))
print("find: " + str(cnt_find_name))
print("faculty with affiliation: " + str(cnt_find_institution))
