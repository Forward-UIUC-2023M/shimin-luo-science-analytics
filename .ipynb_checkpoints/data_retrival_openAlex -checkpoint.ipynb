# %%
import json
import pandas as pd
import csv
import requests

with open('faculty.json', 'r') as file:
    json_data = file.read()

# Parse JSON data
data = json.loads(json_data)

# %%
# Check to see if the same faculty member works in different schools
faculty_map = {}
cnt = 0
for element in data:
    person = element['name']
    institution = element['affiliation']['id']
    # print(str(person)+ " " + str(institution))
    flag = True
    if person in faculty_map:
        print("aaa")
        if faculty_map[person] == institution:
            flag = False
    if flag:
        faculty_map[person] = institution
    else:
        cnt = cnt + 1
print(cnt)
# Out:
# 0

# %%
# Save faculty and institution information
faculty_map = {}
# clean the names
for element in data:
    person = element['name'].strip().replace(", Ph.D.", "").replace(", M.S.", "").replace(", PhD", "").replace("Dr. ", "").replace("Mr. ", "").replace('&', ' ')
    institution = element['affiliation']['name']
    faculty_map[person] = institution

csv_file_path = 'faculty.csv'
# 写入CSV文件
with open(csv_file_path, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    for key, value in faculty_map.items():
        writer.writerow([key, value])

print("faculty.csv has been created.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26424\1762408336.py in <module>
#       2 faculty_map = {}
#       3 # clean the names
# ----> 4 for element in data:
#       5     person = element['name'].strip().replace(", Ph.D.", "").replace(", M.S.", "").replace(", PhD", "").replace("Dr. ", "").replace("Mr. ", "").replace('&', ' ')
#       6     institution = element['affiliation']['name']
#
# NameError: name 'data' is not defined

# %%
# Process institution information
df_institution = pd.DataFrame(columns=['id', 'name', 'photoUrl'])

for element in data:
    institution = element['affiliation']
    new_row = {'id': institution['id'], 'name': institution['name'], 'photoUrl': institution['photoUrl']}
    if new_row['id'] not in df_institution['id'].values:
        df_institution = pd.concat([df_institution, pd.DataFrame([new_row])], ignore_index=True)

# df_institution.to_csv('institution.csv', index=False)
# df_institution

# %%
# Standardize the Institution name to OpemAlex format
institution_url = 'https://api.openalex.org/institutions?search={}'
institution_map = {}
output_file = 'institution_map.txt'

with open(output_file, 'w') as file:
    for index, row in df_institution.iterrows():
        name = row['name']
        file.write("search " + str(index) +": " + name+ "\n")
        url = institution_url.format(name)
        # print('\n' + url)
        page_with_results = requests.get(url).json()

        # store standard institution names and id
        results = page_with_results['results']
        # If the name of an organization is the same in the json file as it is in OpenAlex
        if len(results) > 0 and name == results[0]['display_name']:
            file.write(name+ "\n")
            file.write("id: " + results[0]['id'] + "\n")
            # institution_map[name] = name
            institution_map[name] = []
            institution_map[name].append(results[0]['id'])
            file.write("\n")
            continue
        file.write("======\n")
        # If the name is not exactly the same
        for i,res in enumerate(results):
            res_institution = res['display_name']
            institution_map[name] = []
            if name == 'University of Michigan':
                institution_map[name].append(res['id'])
                file.write(res_institution + ' ' + res['id'] + "\n")
            elif i == 0:
                institution_map[name].append(res['id'])
                file.write(res_institution  + ' ' + res['id'] + "\n")
        file.write("\n")
print(len(institution_map))
# Out:
# 87

# %%
# 手动添加遗漏数据
institution_map['College of William Mary'] = ['https://openalex.org/I16285277']
institution_map['University of illinois at Urbana Champaign'] = ['https://openalex.org/I157725225']
institution_map['University at Buffalo--SUNY'] = ['https://openalex.org/I63190737']
institution_map['Stony Brook University--SUNY'] = ['https://openalex.org/I59553526']
institution_map['University of Minnesota--Twin Cities'] = ['https://openalex.org/I130238516']
institution_map['University of Minnesota--Provo'] = ['https://openalex.org/I130238516']
institution_map['Pennsylvania State University--University Park'] = ['https://openalex.org/I130769515']
institution_map['Binghamton University--SUNY'] = ['https://openalex.org/I123946342']
institution_map['Rutgers University--New Brunswick'] = ['https://openalex.org/I102322142','https://openalex.org/I195342982']
institution_map['University of Pittsburgh--Pittsburgh Campus'] = ['https://openalex.org/I170201317']
institution_map['Brigham Young University--Provo'] = ['https://openalex.org/I100005738','https://openalex.org/I43943889','https://openalex.org/I110092051']
print(len(institution_map))
# Out:
# 98

# %%
# # 手动添加遗漏数据
# institution_map['College of William Mary'] = 'William & Mary'
# institution_map['University of illinois at Urbana Champaign'] = 'University of Illinois Urbana-Champaign'
# institution_map['University at Buffalo--SUNY'] = 'University at Buffalo, State University of New York'
# institution_map['Stony Brook University--SUNY'] = 'Stony Brook University'
# institution_map['University of Minnesota--Twin Cities'] = 'University of Minnesota'
# institution_map['University of Minnesota--Provo'] = 'University of Minnesota'
# institution_map['Pennsylvania State University--University Park'] = 'Pennsylvania State University'
# institution_map['Binghamton University--SUNY'] = 'Binghamton University'
# institution_map['Rutgers University--New Brunswick'] = 'Rutgers, The State University of New Jersey'
# institution_map['University of Pittsburgh--Pittsburgh Campus'] = 'University of Pittsburgh'
# # 特殊处理下密歇根
# institution_map['University of Michigan'] = 'University of Michigan'
# print(len(institution_map))

# %%
# Process and store institution node information
institution_info = pd.DataFrame(columns=['id', 'ror', 'name','relevance_score', 'country_code'])
institution_url = 'https://api.openalex.org/institutions?search={}'
institution_id = {}

for key, value in institution_map.items():
    url = institution_url.format(value.replace('&', ' '))
    print('\n' + url)
    page_with_results = requests.get(url).json()

    results = page_with_results['results']
    if len(results) > 0:
        res = results[0]
        new_row = {'id': res['id'], 'ror': res['ror'], 'name': res['display_name'], 'relevance_score': res['relevance_score'], 'country_code': res['country_code']}
        institution_info = pd.concat([institution_info, pd.DataFrame([new_row])], ignore_index=True)
        institution_id[res['display_name']] = res['id']
institution_info.to_csv('institution_info.csv', index=False)
print("create institution_info.csv")
# Out:
# https://api.openalex.org/institutions?search=University of Rochester
#
# https://api.openalex.org/institutions?search=Emory University
#
# https://api.openalex.org/institutions?search=University of California, Berkeley
#
# https://api.openalex.org/institutions?search=Carnegie Mellon University
#
# https://api.openalex.org/institutions?search=Harvard University
#
# https://api.openalex.org/institutions?search=Northwestern University
#
# https://api.openalex.org/institutions?search=Cornell University
#
# https://api.openalex.org/institutions?search=Case Western Reserve University
#
# https://api.openalex.org/institutions?search=Yale University
#
# https://api.openalex.org/institutions?search=Johns Hopkins University
#
# https://api.openalex.org/institutions?search=University of California, Los Angeles
#
# https://api.openalex.org/institutions?search=University of Florida
#
# https://api.openalex.org/institutions?search=Wake Forest University
#
# https://api.openalex.org/institutions?search=University of California, San Diego
#
# https://api.openalex.org/institutions?search=University of California, Irvine
#
# https://api.openalex.org/institutions?search=Boston University
#
# https://api.openalex.org/institutions?search=New York University
#
# https://api.openalex.org/institutions?search=Lehigh University
#
# https://api.openalex.org/institutions?search=Georgetown University
#
# https://api.openalex.org/institutions?search=University of Southern California
#
# https://api.openalex.org/institutions?search=Tufts University
#
# https://api.openalex.org/institutions?search=University of Notre Dame
#
# https://api.openalex.org/institutions?search=University of Wisconsin–Madison
#
# https://api.openalex.org/institutions?search=University of Chicago
#
# https://api.openalex.org/institutions?search=Tulane University
#
# https://api.openalex.org/institutions?search=Stanford University
#
# https://api.openalex.org/institutions?search=University of Pennsylvania
#
# https://api.openalex.org/institutions?search=Brandeis University
#
# https://api.openalex.org/institutions?search=Northeastern University
#
# https://api.openalex.org/institutions?search=Columbia University
#
# https://api.openalex.org/institutions?search=Duke University
#
# https://api.openalex.org/institutions?search=Massachusetts Institute of Technology
#
# https://api.openalex.org/institutions?search=University of Virginia
#
# https://api.openalex.org/institutions?search=Dartmouth College
#
# https://api.openalex.org/institutions?search=Vanderbilt University
#
# https://api.openalex.org/institutions?search=The University of Texas at Austin
#
# https://api.openalex.org/institutions?search=University of North Carolina at Chapel Hill
#
# https://api.openalex.org/institutions?search=Rice University
#
# https://api.openalex.org/institutions?search=Georgia Institute of Technology
#
# https://api.openalex.org/institutions?search=Washington University in St. Louis
#
# https://api.openalex.org/institutions?search=Boston College
#
# https://api.openalex.org/institutions?search=University of Michigan
#
# https://api.openalex.org/institutions?search=California Institute of Technology
#
# https://api.openalex.org/institutions?search=Brown University
#
# https://api.openalex.org/institutions?search=University of California, Santa Barbara
#
# https://api.openalex.org/institutions?search=University of Georgia
#
# https://api.openalex.org/institutions?search=University of California, Davis
#
# https://api.openalex.org/institutions?search=Princeton University
#
# https://api.openalex.org/institutions?search=Auburn University
#
# https://api.openalex.org/institutions?search=Fordham University
#
# https://api.openalex.org/institutions?search=University of Maryland, College Park
#
# https://api.openalex.org/institutions?search=Howard University
#
# https://api.openalex.org/institutions?search=Texas A M University
#
# https://api.openalex.org/institutions?search=University of Massachusetts Amherst
#
# https://api.openalex.org/institutions?search=Purdue University West Lafayette
#
# https://api.openalex.org/institutions?search=George Washington University
#
# https://api.openalex.org/institutions?search=Indiana University Bloomington
#
# https://api.openalex.org/institutions?search=University of Iowa
#
# https://api.openalex.org/institutions?search=University of California, Santa Cruz
#
# https://api.openalex.org/institutions?search=Pepperdine University
#
# https://api.openalex.org/institutions?search=American University
#
# https://api.openalex.org/institutions?search=Villanova University
#
# https://api.openalex.org/institutions?search=Florida State University
#
# https://api.openalex.org/institutions?search=University of California, San Diego
#
# https://api.openalex.org/institutions?search=Virginia Tech
#
# https://api.openalex.org/institutions?search=Santa Clara University
#
# https://api.openalex.org/institutions?search=University of California, Merced
#
# https://api.openalex.org/institutions?search=University of California, Riverside
#
# https://api.openalex.org/institutions?search=Clemson University
#
# https://api.openalex.org/institutions?search=Michigan State University
#
# https://api.openalex.org/institutions?search=Worcester Polytechnic Institute
#
# https://api.openalex.org/institutions?search=University of Denver
#
# https://api.openalex.org/institutions?search=Colorado School of Mines
#
# https://api.openalex.org/institutions?search=Texas Christian University
#
# https://api.openalex.org/institutions?search=Gonzaga University
#
# https://api.openalex.org/institutions?search=Elon University
#
# https://api.openalex.org/institutions?search=Baylor University
#
# https://api.openalex.org/institutions?search=Stevens Institute of Technology
#
# https://api.openalex.org/institutions?search=Southern Methodist University
#
# https://api.openalex.org/institutions?search=North Carolina State University
#
# https://api.openalex.org/institutions?search=Yeshiva University
#
# https://api.openalex.org/institutions?search=Rensselaer Polytechnic Institute
#
# https://api.openalex.org/institutions?search=University of Miami
#
# https://api.openalex.org/institutions?search=University of Arizona
#
# https://api.openalex.org/institutions?search=University of Washington
#
# https://api.openalex.org/institutions?search=Syracuse University
#
# https://api.openalex.org/institutions?search=Marquette University
#
# https://api.openalex.org/institutions?search=William   Mary
#
# https://api.openalex.org/institutions?search=University of Illinois Urbana-Champaign
#
# https://api.openalex.org/institutions?search=University at Buffalo, State University of New York
#
# https://api.openalex.org/institutions?search=Stony Brook University
#
# https://api.openalex.org/institutions?search=University of Minnesota
#
# https://api.openalex.org/institutions?search=University of Minnesota
#
# https://api.openalex.org/institutions?search=Pennsylvania State University
#
# https://api.openalex.org/institutions?search=Binghamton University
#
# https://api.openalex.org/institutions?search=Rutgers, The State University of New Jersey
#
# https://api.openalex.org/institutions?search=University of Pittsburgh
# 已创建：institution_info.csv

# %%
# print(find_cnt)
# author_url_with_page = 'https://api.openalex.org/authors?search={}&select=id,display_name,last_known_institution,works_api_url&page={}'
#
# output_file = "find_info.txt"
# with open(output_file, 'w') as file:
#
#     for author, institution in faculty_map.items():
#         if author in is_find:
#             print("continue")
#             continue
#         # file.write((author+" | "+ institution+"\n")
#         # string = author + " | " + institution + "\n"
#         # encoded_string = string.encode('utf-8')  # 转换为utf-8编码
#         # file.write(encoded_string.decode('utf-8'))
#
#         print(author+" "+ institution)
#         page = 1
#         has_more_pages = True
#         not_stop = True
#
#         # loop through pages
#         while has_more_pages and not_stop:
#
#             # set page value and request page from OpenAlex
#             url = author_url_with_page.format(author,page)
#             print(url)
#             # file.write(url+"\n")
#             # string = url+"\n"
#             # encoded_string = string.encode('utf-8')  # 转换为utf-8编码
#             # file.write(encoded_string.decode('utf-8'))
#
#             page_with_results = requests.get(url).json()
#
#             # loop through partial list of results
#             results = page_with_results['results']
#             flag = False
#             for i,res in enumerate(results):
#                 if res['last_known_institution'] is None:
#                     continue
#                 res_institution = res['last_known_institution']['display_name']
#                 # print(res_institution)
#                 # print(institution_map[institution])
#                 if res_institution.find(institution_map[institution]) != -1:
#                     new_row = {'author': author, 'institution': res['last_known_institution']['id'], 'works_url': res['works_api_url']}
#                     whole_info = pd.concat([whole_info, pd.DataFrame([new_row])], ignore_index=True)
#                     print("find!")
#                     file.write("find!"+"\n")
#                     print(res['works_api_url'])
#                     file.write(res['works_api_url']+"\n")
#                     flag = True
#                     find_cnt = find_cnt + 1
#                     is_find.append(author)
#                     break
#             if flag:
#                 break
#             # next page
#             page += 1
#
#             # end loop when either there are no more results on the requested page
#             # or the next request would exceed 10,000 results
#             per_page = page_with_results['meta']['per_page']
#             has_more_pages = len(results) == per_page
#             not_stop = page < 40
#             if ~not_stop:
#                 is_find.append(author)
#         print()
#         file.write("\n")
#     print(find_cnt)
#     file.write("find: "+find_cnt+"\n")
# whole_info
# Out:
# 895
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# Aparna Bharati Lehigh University
# https://api.openalex.org/authors?search=Aparna Bharati&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A2230669681
#
# Arielle Carr Lehigh University
# https://api.openalex.org/authors?search=Arielle Carr&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4316002536
#
# Brian Y. Chen Lehigh University
# https://api.openalex.org/authors?search=Brian Y. Chen&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Liang Cheng Lehigh University
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=1
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=2
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=3
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=4
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=5
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=6
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=7
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=8
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=9
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=10
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=11
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=12
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=13
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=14
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=15
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=16
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=17
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=18
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=19
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=20
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=21
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=22
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=23
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=24
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=25
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=26
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=27
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=28
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=29
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=30
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=31
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=32
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=33
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=34
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=35
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=36
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=37
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=38
# https://api.openalex.org/authors?search=Liang Cheng&select=id,display_name,last_known_institution,works_api_url&page=39
#
# Mooi Choo Chuah Lehigh University
# https://api.openalex.org/authors?search=Mooi Choo Chuah&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A2141761699
#
# Brian D. Davison Lehigh University
# https://api.openalex.org/authors?search=Brian D. Davison&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4355339910
#
# Dominic DiFranzo Lehigh University
# https://api.openalex.org/authors?search=Dominic DiFranzo&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4340172564
#
# Mark Erle Lehigh University
# https://api.openalex.org/authors?search=Mark Erle&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Ahmed Hassan Lehigh University
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=1
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=2
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=3
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=4
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=5
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=6
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=7
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=8
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=9
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=10
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=11
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=12
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=13
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=14
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=15
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=16
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=17
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=18
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=19
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=20
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=21
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=22
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=23
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=24
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=25
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=26
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=27
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=28
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=29
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=30
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=31
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=32
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=33
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=34
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=35
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=36
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=37
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=38
# https://api.openalex.org/authors?search=Ahmed Hassan&select=id,display_name,last_known_institution,works_api_url&page=39
#
# Lifang He Lehigh University
# https://api.openalex.org/authors?search=Lifang He&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4359337112
#
# Jeffrey D. Heflin Lehigh University
# https://api.openalex.org/authors?search=Jeffrey D. Heflin&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Sharon M. Kalafut Lehigh University
# https://api.openalex.org/authors?search=Sharon M. Kalafut&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Hank (Henry) Korth Lehigh University
# https://api.openalex.org/authors?search=Hank (Henry) Korth&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Daniel P. Lopresti Lehigh University
# https://api.openalex.org/authors?search=Daniel P. Lopresti&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4335800483
#
# Corey Montella Lehigh University
# https://api.openalex.org/authors?search=Corey Montella&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A2085917238
#
# Hector Munoz-Avila Lehigh University
# https://api.openalex.org/authors?search=Hector Munoz-Avila&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4347911250
#
# Houria Oudghiri Lehigh University
# https://api.openalex.org/authors?search=Houria Oudghiri&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Roberto Palmieri Lehigh University
# https://api.openalex.org/authors?search=Roberto Palmieri&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4332230926
#
# William Phillips Lehigh University
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=1
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=2
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=3
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=4
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=5
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=6
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=7
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=8
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=9
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=10
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=11
# https://api.openalex.org/authors?search=William Phillips&select=id,display_name,last_known_institution,works_api_url&page=12
#
# David Saldaña Lehigh University
# https://api.openalex.org/authors?search=David Saldaña&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A2100698204
#
# Michael F. Spear Lehigh University
# https://api.openalex.org/authors?search=Michael F. Spear&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Jeffrey C. Trinkle Lehigh University
# https://api.openalex.org/authors?search=Jeffrey C. Trinkle&select=id,display_name,last_known_institution,works_api_url&page=1
#
# George Witmer Lehigh University
# https://api.openalex.org/authors?search=George Witmer&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Sihong Xie Lehigh University
# https://api.openalex.org/authors?search=Sihong Xie&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4334282833
#
# Kallie Ziltz Lehigh University
# https://api.openalex.org/authors?search=Kallie Ziltz&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Matt Blaze Georgetown University
# https://api.openalex.org/authors?search=Matt Blaze&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Philip Buffum Georgetown University
# https://api.openalex.org/authors?search=Philip Buffum&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Eric Burger Georgetown University
# https://api.openalex.org/authors?search=Eric Burger&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4337827505
#
# Ray Essick Georgetown University
# https://api.openalex.org/authors?search=Ray Essick&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Jeremy Fineman Georgetown University
# https://api.openalex.org/authors?search=Jeremy Fineman&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4357202992
#
# Ophir Frieder Georgetown University
# https://api.openalex.org/authors?search=Ophir Frieder&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A1975479660
#
# Nazli Goharian Georgetown University
# https://api.openalex.org/authors?search=Nazli Goharian&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4354660187
#
# Sasha Golovnev Georgetown University
# https://api.openalex.org/authors?search=Sasha Golovnev&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Bala Kalyanasundaram Georgetown University
# https://api.openalex.org/authors?search=Bala Kalyanasundaram&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4348887239
#
# Mark Maloof Georgetown University
# https://api.openalex.org/authors?search=Mark Maloof&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Shin #8217;ichiro Matsuo Georgetown University
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=1
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=2
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=3
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=4
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=5
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=6
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=7
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=8
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=9
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=10
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=11
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=12
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=13
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=14
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=15
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=16
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=17
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=18
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=19
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=20
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=21
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=22
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=23
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=24
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=25
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=26
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=27
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=28
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=29
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=30
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=31
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=32
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=33
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=34
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=35
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=36
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=37
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=38
# https://api.openalex.org/authors?search=Shin #8217;ichiro Matsuo&select=id,display_name,last_known_institution,works_api_url&page=39
#
# Jami Montgomery Georgetown University
# https://api.openalex.org/authors?search=Jami Montgomery&select=id,display_name,last_known_institution,works_api_url&page=1
#
# Calvin Newport Georgetown University
# https://api.openalex.org/authors?search=Calvin Newport&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4337037752
#
# Kobbi Nissim Georgetown University
# https://api.openalex.org/authors?search=Kobbi Nissim&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4357255071
#
# Nathan Schneider Georgetown University
# https://api.openalex.org/authors?search=Nathan Schneider&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4357535631
#
# Micah Sherr Georgetown University
# https://api.openalex.org/authors?search=Micah Sherr&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A2046649793
#
# Clay Shields Georgetown University
# https://api.openalex.org/authors?search=Clay Shields&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4339457834
#
# Lisa Singh Georgetown University
# https://api.openalex.org/authors?search=Lisa Singh&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4334817230
#
# J. Smart Georgetown University
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=1
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=2
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=3
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=4
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=5
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=6
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=7
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=8
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=9
# https://api.openalex.org/authors?search=J. Smart&select=id,display_name,last_known_institution,works_api_url&page=10
# find!
# https://api.openalex.org/works?filter=author.id:A3157847230
#
# Richard Squier Georgetown University
# https://api.openalex.org/authors?search=Richard Squier&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4348103887
#
# Justin Thaler Georgetown University
# https://api.openalex.org/authors?search=Justin Thaler&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4357485154
#
# Benjamin Ujcich Georgetown University
# https://api.openalex.org/authors?search=Benjamin Ujcich&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A2750624070
#
# Nitin Vaidya Georgetown University
# https://api.openalex.org/authors?search=Nitin Vaidya&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A4359038028
#
# Mahe Velauthapillai Georgetown University
# https://api.openalex.org/authors?search=Mahe Velauthapillai&select=id,display_name,last_known_institution,works_api_url&page=1
# find!
# https://api.openalex.org/works?filter=author.id:A2120187944
#
# Addison Woods Georgetown University
# https://api.openalex.org/authors?search=Addison Woods&select=id,display_name,last_known_institution,works_api_url&page=1
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     699             if is_new_proxy_conn and http_tunnel_required:
# --> 700                 self._prepare_proxy(conn)
#     701
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     995
# --> 996         conn.connect()
#     997
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     413
# --> 414         self.sock = ssl_wrap_socket(
#     415             sock=conn,
#
# D:\Software\Anaconda\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# D:\Software\Anaconda\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# D:\Software\Anaconda\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     500         # ctx._wrap_socket()
# --> 501         return self.sslsocket_class._create(
#     502             sock=sock,
#
# D:\Software\Anaconda\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042             except (OSError, ValueError):
#
# D:\Software\Anaconda\lib\ssl.py in do_handshake(self, block)
#    1309                 self.settimeout(None)
# -> 1310             self._sslobj.do_handshake()
#    1311         finally:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# D:\Software\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='api.openalex.org', port=443): Max retries exceeded with url: /authors?search=Addison%20Woods&select=id,display_name,last_known_institution,works_api_url&page=1 (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None)))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9444\3089146962.py in <module>
#      30             # file.write(encoded_string.decode('utf-8'))
#      31
# ---> 32             page_with_results = requests.get(url).json()
#      33
#      34             # loop through partial list of results
#
# D:\Software\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# D:\Software\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# D:\Software\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# D:\Software\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# D:\Software\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     557
#     558             if isinstance(e.reason, _ProxyError):
# --> 559                 raise ProxyError(e, request=request)
#     560
#     561             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='api.openalex.org', port=443): Max retries exceeded with url: /authors?search=Addison%20Woods&select=id,display_name,last_known_institution,works_api_url&page=1 (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None)))

# %%
total_cnt = 0
find_cnt = 0
whole_info = pd.DataFrame(columns=['author', 'institution', 'works_url'])
is_find = []
not_found = pd.DataFrame(columns=['author', 'institution'])

# %%
# print(find_cnt)

# use "name" and "institution_id" to find "work_url"
author_url_with_page = 'https://api.openalex.org/authors?search={}&filter=last_known_institution.id:{}&select=id,display_name,last_known_institution,works_api_url&per-page=200'
output_file = 'faculty_find_result'

with open(output_file, 'a', encoding='utf-8') as file:
    for author, institution in faculty_map.items():
        # if the author has been searched
        if author in is_find:
            print("continue")
            continue
        flag = False

        print(author+ ' | ' + institution)
        for in_id in institution_map[institution]:
            # set page value and request page from OpenAlex
            url = author_url_with_page.format(author,in_id)
            print(url)
            total_cnt = total_cnt + 1

            page_with_results = requests.get(url).json()
            # loop through partial list of results
            results = page_with_results['results']
            is_find.append(author)
            if len(results) > 0:
                print(author +' | ' +  in_id + ' | ' + str(len(results)))
                file.write( author +' | ' +  in_id + ' | ' + str(len(results))+'\n' )
                for res in results:
                    if res['last_known_institution'] is not None:
                        new_row = {'author': author, 'institution': res['last_known_institution']['id'], 'works_url': res['works_api_url']}
                        whole_info = pd.concat([whole_info, pd.DataFrame([new_row])], ignore_index=True)
                        print("find!")
                        print(res['works_api_url'])
                        find_cnt = find_cnt + 1
                        flag = True
                        break
        if ~flag:
            file.write('Not found: ' + author)
            new_row = {'author': author, 'institution': institution}
            not_found = pd.concat([not_found, pd.DataFrame([new_row])], ignore_index=True)
        print()
        file.write("\n")
    print(find_cnt)
    file.write("find: "+str(find_cnt)+"\n")
whole_info
# Out:
# 1020
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# Michael Ball | University of California--Berkeley
#
# Christian Borgs | University of California--Berkeley
#
# Sarah Chasins | University of California--Berkeley
#
# Jennifer Chayes | University of California--Berkeley
#
# Alvin Cheung | University of California--Berkeley
#
# Natacha Crooks | University of California--Berkeley
#
# Hany Farid | University of California--Berkeley
#
# Nilah Ioannidis | University of California--Berkeley
#
# Jiantao Jiao | University of California--Berkeley
#
# Angjoo Kanazawa | University of California--Berkeley
#
# Jelani Nelson | University of California--Berkeley
#
# Aditya Parameswaran | University of California--Berkeley
#
# Niloufar Salehi | University of California--Berkeley
#
# Sophia Shao | University of California--Berkeley
#
# Jacob Steinhardt | University of California--Berkeley
#
# Avishay Tal | University of California--Berkeley
#
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# Christine Alvarado | University of California--San Diego
#
# Vineet Bafna | University of California--San Diego
#
# Nuno Bandeira | University of California--San Diego
#
# Mihir Bellare | University of California--San Diego
#
# Taylor Berg-Kirkpatrick | University of California--San Diego
#
# Manmohan Chandraker | University of California--San Diego
#
# Kamalika Chaudhuri | University of California--San Diego
#
# C. K. Cheng | University of California--San Diego
#
# Albert Chern | University of California--San Diego
#
# Henrik I. Christensen | University of California--San Diego
#
# Gary Cottrell | University of California--San Diego
#
# Sanjoy Dasgupta | University of California--San Diego
#
# Alin Deutsch | University of California--San Diego
#
# Hadi Esmaeilzadeh | University of California--San Diego
#
# Yoav Freund | University of California--San Diego
#
# Sicun Gao | University of California--San Diego
#
# William G. Griswold | University of California--San Diego
#
# Rajesh K. Gupta | University of California--San Diego
#
# Melissa Gymrek | University of California--San Diego
#
# Nadia Heninger | University of California--San Diego
#
# Russell Impagliazzo | University of California--San Diego
#
# Carlos Jensen | University of California--San Diego
#
# Ranjit Jhala | University of California--San Diego
#
# Andrew B. Kahng | University of California--San Diego
#
# Daniel M. Kane | University of California--San Diego
#
# Ryan Kastner | University of California--San Diego
#
# Pradeep K. Khosla | University of California--San Diego
#
# Scott Klemmer | University of California--San Diego
#
# Rob Knight | University of California--San Diego
#
# David Kriegman | University of California--San Diego
#
# Arun Kumar | University of California--San Diego
#
# Sorin Lerner | University of California--San Diego
#
# Tzu-Mao Li | University of California--San Diego
#
# Shachar Lovett | University of California--San Diego
#
# Julian McAuley | University of California--San Diego
#
# Daniele Micciancio | University of California--San Diego
#
# Mia Minnes | University of California--San Diego
#
# Niema Moshiri | University of California--San Diego
#
# Keith Muller | University of California--San Diego
#
# Ndapa Nakashole | University of California--San Diego
#
# Alex Orailoglu | University of California--San Diego
#
# Alon Orlitsky | University of California--San Diego
#
# Pat Pannuto | University of California--San Diego
#
# Yannis Papakonstantinou | University of California--San Diego
#
# Joseph Pasquale | University of California--San Diego
#
# Ramamohan Paturi | University of California--San Diego
#
# Pavel A. Pevzner | University of California--San Diego
#
# Nadia Polikarpova | University of California--San Diego
#
# Joe Gibbs Politz | University of California--San Diego
#
# Leo Porter | University of California--San Diego
#
# George Porter | University of California--San Diego
#
# Adalbert Gerald Soosai Raj | University of California--San Diego
#
# Ravi Ramamoorthi | University of California--San Diego
#
# Laurel Riek | University of California--San Diego
#
# Tajana Šimunić Rosing | University of California--San Diego
#
# Debashis Sahoo | University of California--San Diego
#
# Lawrence K. Saul | University of California--San Diego
#
# Stefan Savage | University of California--San Diego
#
# Aaron Schulman | University of California--San Diego
#
# Jingbo Shang | University of California--San Diego
#
# Alex C. Snoeren | University of California--San Diego
#
# Deian Stefan | University of California--San Diego
#
# Hao Su | University of California--San Diego
#
# Shankar Subramaniam | University of California--San Diego
#
# Steven Swanson | University of California--San Diego
#
# Dean M. Tullsen | University of California--San Diego
#
# Kristen Vaccaro | University of California--San Diego
#
# Alexander Vardy | University of California--San Diego
#
# Victor Vianu | University of California--San Diego
#
# Geoffrey M. Voelker | University of California--San Diego
#
# Nadir Weibel | University of California--San Diego
#
# Qi (Rose) Yu | University of California--San Diego
#
# Yiying Zhang | University of California--San Diego
#
# Jishen Zhao | University of California--San Diego
#
# Yuanyuan Zhou | University of California--San Diego
#
# Elena Agapie | University of California--Irvine
#
# Iftekhar Ahmed | University of California--Irvine
#
# Shannon Alfaro | University of California--Irvine
#
# Ardalan Amiri Sani | University of California--Irvine
#
# David Armstrong | University of California--Irvine
#
# Pierre Baldi | University of California--Irvine
#
# Brigitte Baldi | University of California--Irvine
#
# Mark Baldwin | University of California--Irvine
#
# Veronica Berrocal | University of California--Irvine
#
# Lubomir Bic | University of California--Irvine
#
# Matt Bietz | University of California--Irvine
#
# Rebecca Black | University of California--Irvine
#
# Geoffrey C Bowker | University of California--Irvine
#
# Elaheh (Eli) Bozorgzadeh | University of California--Irvine
#
# Stacy Branham | University of California--Irvine
#
# Anton Burtsev | University of California--Irvine
#
# Michael J Carey | University of California--Irvine
#
# Yunan Chen | University of California--Irvine
#
# Qi Alfred Chen | University of California--Irvine
#
# Roderic Crooks | University of California--Irvine
#
# Rina Dechter | University of California--Irvine
#
# Brian Demsky | University of California--Irvine
#
# Darren Denenberg | University of California--Irvine
#
# Michael Dillencourt | University of California--Irvine
#
# Mine Dogucu | University of California--Irvine
#
# Paul Dourish | University of California--Irvine
#
# Nikil Dutt | University of California--Irvine
#
# Magda El Zarki | University of California--Irvine
#
# David Eppstein | University of California--Irvine
#
# Daniel Epstein | University of California--Irvine
#
# Julian Feldman | University of California--Irvine
#
# Charless Fowlkes | University of California--Irvine
#
# Roy Fox | University of California--Irvine
#
# Michael Franz | University of California--Irvine
#
# Sergio Gago-Masague | University of California--Irvine
#
# Joshua Garcia | University of California--Irvine
#
# Irene Gassko | University of California--Irvine
#
# Daniel Gillen | University of California--Irvine
#
# Tony Givargis | University of California--Irvine
#
# Michael T. Goodrich | University of California--Irvine
#
# Michele Guindani | University of California--Irvine
#
# Sevan Gulesserian | University of California--Irvine
#
# Ian G. Harris | University of California--Irvine
#
# Wayne B Hayes | University of California--Irvine
#
# Gillian R Hayes | University of California--Irvine
#
# Daniel S. Hirschberg | University of California--Irvine
#
# Mustafa Ibrahim | University of California--Irvine
#
# Alexander Ihler | University of California--Irvine
#
# Mohsen Imani | University of California--Irvine
#
# Sandy Irani | University of California--Irvine
#
# Mimi Ito | University of California--Irvine
#
# Ramesh Jain | University of California--Irvine
#
# Stanislaw Jarecki | University of California--Irvine
#
# Wesley O. Johnson | University of California--Irvine
#
# James A. Jones | University of California--Irvine
#
# Scott Jordan | University of California--Irvine
#
# Sang-Woo Jun | University of California--Irvine
#
# Sangeetha A Jyothi | University of California--Irvine
#
# Kalev Kask | University of California--Irvine
#
# David G. Kay | University of California--Irvine
#
# Dennis Kibler | University of California--Irvine
#
# Ray Klefstad | University of California--Irvine
#
# Alfred Kobsa | University of California--Irvine
#
# Alberto Krone-Martins | University of California--Irvine
#
# Richard Lathrop | University of California--Irvine
#
# Marco Levorato | University of California--Irvine
#
# Chen Li | University of California--Irvine
#
# Cristina V. Lopes | University of California--Irvine
#
# George S. Lueker | University of California--Irvine
#
# Scott Mahlke | University of California--Irvine
#
# Aditi Majumder | University of California--Irvine
#
# Sam Malek | University of California--Irvine
#
# Stephan Mandt | University of California--Irvine
#
# Gloria Mark | University of California--Irvine
#
# Melissa Mazmanian | University of California--Irvine
#
# Gopi Meenakshisundaram | University of California--Irvine
#
# Sharad Mehrotra | University of California--Irvine
#
# Milena Mihail | University of California--Irvine
#
# Vladimir Minin | University of California--Irvine
#
# Eric Mjolsness | University of California--Irvine
#
# Bin Nan | University of California--Irvine
#
# Bonnie Nardi | University of California--Irvine
#
# Emily Navarro | University of California--Irvine
#
# Alexandru Nicolau | University of California--Irvine
#
# Judy Olson | University of California--Irvine
#
# Gary M. Olson | University of California--Irvine
#
# Marios Papaefthymiou | University of California--Irvine
#
# Richard E Pattis | University of California--Irvine
#
# Kylie Peppler | University of California--Irvine
#
# Anne Marie Piper | University of California--Irvine
#
# Tianchen Qian | University of California--Irvine
#
# Annie Qu | University of California--Irvine
#
# David Redmiles | University of California--Irvine
#
# Amelia C. Regan | University of California--Irvine
#
# Debra J. Richardson | University of California--Irvine
#
# Katie Salen Tekinbas | University of California--Irvine
#
# Isaac D. Scherson | University of California--Irvine
#
# Babak Shahbaba | University of California--Irvine
#
# Weining Shen | University of California--Irvine
#
# Michael Shindler | University of California--Irvine
#
# Sameer Singh | University of California--Irvine
#
# Padhraic Smyth | University of California--Irvine
#
# Kurt Squire | University of California--Irvine
#
# Thomas A. Standish | University of California--Irvine
#
# Constance Steinkuehler | University of California--Irvine
#
# Hal Stern | University of California--Irvine
#
# Erik Sudderth | University of California--Irvine
#
# Theresa Jean Tanenbaum | University of California--Irvine
#
# Richard Taylor | University of California--Irvine
#
# Alex Thornton | University of California--Irvine
#
# Bill Tomlinson | University of California--Irvine
#
# Aaron Trammell | University of California--Irvine
#
# Gene Tsudik | University of California--Irvine
#
# Jessica Utts | University of California--Irvine
#
# Andre van der Hoek | University of California--Irvine
#
# Vijay Vazirani | University of California--Irvine
#
# Alexander Veidenbaum | University of California--Irvine
#
# Nalini Venkatasubramanian | University of California--Irvine
#
# Jennifer Wong-Ma | University of California--Irvine
#
# Xiaohui Xie | University of California--Irvine
#
# Sean Young | University of California--Irvine
#
# Neil Young | University of California--Irvine
#
# Yaming Yu | University of California--Irvine
#
# Zhaoxia Yu | University of California--Irvine
#
# Jing Zhang | University of California--Irvine
#
# Shuang Zhao | University of California--Irvine
#
# Kai Zheng | University of California--Irvine
#
# Hadar Ziv | University of California--Irvine
#
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# Robert Rand (effective July 1) | University of Chicago
# https://api.openalex.org/authors?search=Robert Rand (effective July 1)&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Alexander A. Razborov | University of Chicago
# https://api.openalex.org/authors?search=Alexander A. Razborov&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Alexander A. Razborov | https://openalex.org/I40347166 | 6
# find!
# https://api.openalex.org/works?filter=author.id:A4338631920
#
# John H. Reppy | University of Chicago
# https://api.openalex.org/authors?search=John H. Reppy&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Anne Rogers | University of Chicago
# https://api.openalex.org/authors?search=Anne Rogers&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Lamont Kenneth Samuels | University of Chicago
# https://api.openalex.org/authors?search=Lamont Kenneth Samuels&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# L. Ridgway Scott | University of Chicago
# https://api.openalex.org/authors?search=L. Ridgway Scott&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# L. Ridgway Scott | https://openalex.org/I40347166 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A4358460596
#
# Sarah Sebo | University of Chicago
# https://api.openalex.org/authors?search=Sarah Sebo&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Sarah Sebo | https://openalex.org/I40347166 | 5
# find!
# https://api.openalex.org/works?filter=author.id:A4299342084
#
# Gregory Shakhnarovich | University of Chicago
# https://api.openalex.org/authors?search=Gregory Shakhnarovich&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Adam Shaw | University of Chicago
# https://api.openalex.org/authors?search=Adam Shaw&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Janos Simon | University of Chicago
# https://api.openalex.org/authors?search=Janos Simon&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Janos Simon | https://openalex.org/I40347166 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A4335080590
#
# Robert Soare | University of Chicago
# https://api.openalex.org/authors?search=Robert Soare&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Robert Soare | https://openalex.org/I40347166 | 5
# find!
# https://api.openalex.org/works?filter=author.id:A4342792925
#
# Borja Sotomayor | University of Chicago
# https://api.openalex.org/authors?search=Borja Sotomayor&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Borja Sotomayor | https://openalex.org/I40347166 | 3
# find!
# https://api.openalex.org/works?filter=author.id:A2146217113
#
# Nathan Srebro | University of Chicago
# https://api.openalex.org/authors?search=Nathan Srebro&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Nathan Srebro | https://openalex.org/I40347166 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A4307136563
#
# Rick Stevens | University of Chicago
# https://api.openalex.org/authors?search=Rick Stevens&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Rick Stevens | https://openalex.org/I40347166 | 10
# find!
# https://api.openalex.org/works?filter=author.id:A4358579947
#
# Madhur Tulsiani | University of Chicago
# https://api.openalex.org/authors?search=Madhur Tulsiani&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Blase Ur | University of Chicago
# https://api.openalex.org/authors?search=Blase Ur&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Blase Ur | https://openalex.org/I40347166 | 5
# find!
# https://api.openalex.org/works?filter=author.id:A2077543365
#
# Matthew Wachs | University of Chicago
# https://api.openalex.org/authors?search=Matthew Wachs&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Matthew Walter | University of Chicago
# https://api.openalex.org/authors?search=Matthew Walter&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Rebecca Willett | University of Chicago
# https://api.openalex.org/authors?search=Rebecca Willett&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Rebecca Willett | https://openalex.org/I40347166 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4353128516
#
# Ben Y. Zhao | University of Chicago
# https://api.openalex.org/authors?search=Ben Y. Zhao&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Ben Y. Zhao | https://openalex.org/I40347166 | 23
# find!
# https://api.openalex.org/works?filter=author.id:A4358546009
#
# Heather Zheng | University of Chicago
# https://api.openalex.org/authors?search=Heather Zheng&filter=last_known_institution.id:https://openalex.org/I40347166&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Michael Mislove | Tulane University
# https://api.openalex.org/authors?search=Michael Mislove&filter=last_known_institution.id:https://openalex.org/I114832834&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Michael Mislove | https://openalex.org/I114832834 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A2577197900
#
# Carola Wenk | Tulane University
# https://api.openalex.org/authors?search=Carola Wenk&filter=last_known_institution.id:https://openalex.org/I114832834&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Carola Wenk | https://openalex.org/I114832834 | 2
# find!
# https://api.openalex.org/works?filter=author.id:A2130147369
#
# Ramgopal Mettu | Tulane University
# https://api.openalex.org/authors?search=Ramgopal Mettu&filter=last_known_institution.id:https://openalex.org/I114832834&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Ramgopal Mettu | https://openalex.org/I114832834 | 10
# find!
# https://api.openalex.org/works?filter=author.id:A4359435564
#
# Jihun Hamm | Tulane University
# https://api.openalex.org/authors?search=Jihun Hamm&filter=last_known_institution.id:https://openalex.org/I114832834&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Jihun Hamm | https://openalex.org/I114832834 | 3
# find!
# https://api.openalex.org/works?filter=author.id:A3190939322
#
# Aron Culotta | Tulane University
# https://api.openalex.org/authors?search=Aron Culotta&filter=last_known_institution.id:https://openalex.org/I114832834&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Aron Culotta | https://openalex.org/I114832834 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A4358815439
#
# Brian Summa | Tulane University
# https://api.openalex.org/authors?search=Brian Summa&filter=last_known_institution.id:https://openalex.org/I114832834&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Brian Summa | https://openalex.org/I114832834 | 6
# find!
# https://api.openalex.org/works?filter=author.id:A2059514868
#
# Zizhan Zheng | Tulane University
# https://api.openalex.org/authors?search=Zizhan Zheng&filter=last_known_institution.id:https://openalex.org/I114832834&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Zizhan Zheng | https://openalex.org/I114832834 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A2168714274
#
# Sara Achour | Stanford University
# https://api.openalex.org/authors?search=Sara Achour&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Maneesh Agrawala | Stanford University
# https://api.openalex.org/authors?search=Maneesh Agrawala&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Maneesh Agrawala | https://openalex.org/I97018004 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A718039462
#
# Alex Aiken | Stanford University
# https://api.openalex.org/authors?search=Alex Aiken&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Alex Aiken | https://openalex.org/I97018004 | 6
# find!
# https://api.openalex.org/works?filter=author.id:A4302790961
#
# Nima Anari | Stanford University
# https://api.openalex.org/authors?search=Nima Anari&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Nima Anari | https://openalex.org/I97018004 | 3
# find!
# https://api.openalex.org/works?filter=author.id:A4353275361
#
# Peter Bailis | Stanford University
# https://api.openalex.org/authors?search=Peter Bailis&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Peter Bailis | https://openalex.org/I97018004 | 7
# find!
# https://api.openalex.org/works?filter=author.id:A4353955028
#
# Clark Barrett | Stanford University
# https://api.openalex.org/authors?search=Clark Barrett&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Clark Barrett | https://openalex.org/I97018004 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4352755624
#
# Gill Bejerano | Stanford University
# https://api.openalex.org/authors?search=Gill Bejerano&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Gill Bejerano | https://openalex.org/I97018004 | 3
# find!
# https://api.openalex.org/works?filter=author.id:A4344974112
#
# Michael Bernstein | Stanford University
# https://api.openalex.org/authors?search=Michael Bernstein&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Michael Bernstein | https://openalex.org/I97018004 | 35
# find!
# https://api.openalex.org/works?filter=author.id:A4353478310
#
# Jeannette Bohg | Stanford University
# https://api.openalex.org/authors?search=Jeannette Bohg&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Jeannette Bohg | https://openalex.org/I97018004 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A66685338
#
# Dan Boneh | Stanford University
# https://api.openalex.org/authors?search=Dan Boneh&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Dan Boneh | https://openalex.org/I97018004 | 6
# find!
# https://api.openalex.org/works?filter=author.id:A4357382986
#
# Emma Brunskill | Stanford University
# https://api.openalex.org/authors?search=Emma Brunskill&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Emma Brunskill | https://openalex.org/I97018004 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4359216847
#
# Moses Charikar | Stanford University
# https://api.openalex.org/authors?search=Moses Charikar&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Moses Charikar | https://openalex.org/I97018004 | 10
# find!
# https://api.openalex.org/works?filter=author.id:A4359593593
#
# Bill Dally | Stanford University
# https://api.openalex.org/authors?search=Bill Dally&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Bill Dally | https://openalex.org/I97018004 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A2146965333
#
# Ron Dror | Stanford University
# https://api.openalex.org/authors?search=Ron Dror&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Ron Dror | https://openalex.org/I97018004 | 12
# find!
# https://api.openalex.org/works?filter=author.id:A4353123476
#
# Zakir Durumeric | Stanford University
# https://api.openalex.org/authors?search=Zakir Durumeric&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Zakir Durumeric | https://openalex.org/I97018004 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A169368957
#
# Dawson Engler | Stanford University
# https://api.openalex.org/authors?search=Dawson Engler&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Dawson Engler | https://openalex.org/I97018004 | 3
# find!
# https://api.openalex.org/works?filter=author.id:A4334300165
#
# Stefano Ermon | Stanford University
# https://api.openalex.org/authors?search=Stefano Ermon&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Stefano Ermon | https://openalex.org/I97018004 | 7
# find!
# https://api.openalex.org/works?filter=author.id:A4355084960
#
# Kayvon Fatahalian | Stanford University
# https://api.openalex.org/authors?search=Kayvon Fatahalian&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Kayvon Fatahalian | https://openalex.org/I97018004 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A31390454
#
# Ron Fedkiw | Stanford University
# https://api.openalex.org/authors?search=Ron Fedkiw&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Chelsea Finn | Stanford University
# https://api.openalex.org/authors?search=Chelsea Finn&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Chelsea Finn | https://openalex.org/I97018004 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A4383144884
#
# Mike Genesereth | Stanford University
# https://api.openalex.org/authors?search=Mike Genesereth&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Noah Goodman | Stanford University
# https://api.openalex.org/authors?search=Noah Goodman&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Noah Goodman | https://openalex.org/I97018004 | 11
# find!
# https://api.openalex.org/works?filter=author.id:A4355570924
#
# Leonidas Guibas | Stanford University
# https://api.openalex.org/authors?search=Leonidas Guibas&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Leonidas Guibas | https://openalex.org/I97018004 | 20
# find!
# https://api.openalex.org/works?filter=author.id:A4355454454
#
# Patrick Hanrahan | Stanford University
# https://api.openalex.org/authors?search=Patrick Hanrahan&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Tatsu Hashimoto | Stanford University
# https://api.openalex.org/authors?search=Tatsu Hashimoto&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# John Hennessy | Stanford University
# https://api.openalex.org/authors?search=John Hennessy&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# John Hennessy | https://openalex.org/I97018004 | 32
# find!
# https://api.openalex.org/works?filter=author.id:A4356007984
#
# Mark Horowitz | Stanford University
# https://api.openalex.org/authors?search=Mark Horowitz&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Mark Horowitz | https://openalex.org/I97018004 | 28
# find!
# https://api.openalex.org/works?filter=author.id:A4357255042
#
# Doug James | Stanford University
# https://api.openalex.org/authors?search=Doug James&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Doug James | https://openalex.org/I97018004 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4349638773
#
# Dan Jurafsky | Stanford University
# https://api.openalex.org/authors?search=Dan Jurafsky&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Dan Jurafsky | https://openalex.org/I97018004 | 7
# find!
# https://api.openalex.org/works?filter=author.id:A4338408888
#
# Sachin Katti | Stanford University
# https://api.openalex.org/authors?search=Sachin Katti&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Sachin Katti | https://openalex.org/I97018004 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4356043347
#
# Oussama Khatib | Stanford University
# https://api.openalex.org/authors?search=Oussama Khatib&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Oussama Khatib | https://openalex.org/I97018004 | 6
# find!
# https://api.openalex.org/works?filter=author.id:A2135302480
#
# Fred Kjoelstad | Stanford University
# https://api.openalex.org/authors?search=Fred Kjoelstad&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Fred Kjolstad | Stanford University
# https://api.openalex.org/authors?search=Fred Kjolstad&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Christos Kozyrakis | Stanford University
# https://api.openalex.org/authors?search=Christos Kozyrakis&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Christos Kozyrakis | https://openalex.org/I97018004 | 7
# find!
# https://api.openalex.org/works?filter=author.id:A4355736640
#
# Anshul Kundaje | Stanford University
# https://api.openalex.org/authors?search=Anshul Kundaje&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Anshul Kundaje | https://openalex.org/I97018004 | 16
# find!
# https://api.openalex.org/works?filter=author.id:A4355334880
#
# Monica Lam | Stanford University
# https://api.openalex.org/authors?search=Monica Lam&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Monica Lam | https://openalex.org/I97018004 | 12
# find!
# https://api.openalex.org/works?filter=author.id:A4358616456
#
# James Landay | Stanford University
# https://api.openalex.org/authors?search=James Landay&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# James Landay | https://openalex.org/I97018004 | 10
# find!
# https://api.openalex.org/works?filter=author.id:A4360102500
#
# Jure Leskovec | Stanford University
# https://api.openalex.org/authors?search=Jure Leskovec&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Jure Leskovec | https://openalex.org/I97018004 | 10
# find!
# https://api.openalex.org/works?filter=author.id:A4359485243
#
# Philip Levis | Stanford University
# https://api.openalex.org/authors?search=Philip Levis&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Philip Levis | https://openalex.org/I97018004 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4338831486
#
# Fei-Fei Li | Stanford University
# https://api.openalex.org/authors?search=Fei-Fei Li&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Fei-Fei Li | https://openalex.org/I97018004 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4314697617
#
# Percy Liang | Stanford University
# https://api.openalex.org/authors?search=Percy Liang&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Percy Liang | https://openalex.org/I97018004 | 10
# find!
# https://api.openalex.org/works?filter=author.id:A4353176918
#
# Karen Liu | Stanford University
# https://api.openalex.org/authors?search=Karen Liu&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Karen Liu | https://openalex.org/I97018004 | 5
# find!
# https://api.openalex.org/works?filter=author.id:A4308464335
#
# Tengyu Ma | Stanford University
# https://api.openalex.org/authors?search=Tengyu Ma&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Tengyu Ma | https://openalex.org/I97018004 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A2171800532
#
# Chris Manning | Stanford University
# https://api.openalex.org/authors?search=Chris Manning&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# David Mazieres | Stanford University
# https://api.openalex.org/authors?search=David Mazieres&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# David Mazieres | https://openalex.org/I97018004 | 5
# find!
# https://api.openalex.org/works?filter=author.id:A4334831038
#
# Nick McKeown | Stanford University
# https://api.openalex.org/authors?search=Nick McKeown&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Nick McKeown | https://openalex.org/I97018004 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A4344944121
#
# John Mitchell | Stanford University
# https://api.openalex.org/authors?search=John Mitchell&filter=last_known_institution.id:https://openalex.org/I97018004&select=id,display_name,last_known_institution,works_api_url&per-page=200
# John Mitchell | https://openalex.org/I97018004 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A4323143897
#
# Subhasish Mitra | Stanford University
# ...
# Wenzhan Song | https://openalex.org/I165733156 | 3
# find!
# https://api.openalex.org/works?filter=author.id:A4316835100
#
# Ying Xu | University of Georgia
# https://api.openalex.org/authors?search=Ying Xu&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# William York | University of Georgia
# https://api.openalex.org/authors?search=William York&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Hamid Arabnia | University of Georgia
# https://api.openalex.org/authors?search=Hamid Arabnia&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Hamid Arabnia | https://openalex.org/I165733156 | 7
# find!
# https://api.openalex.org/works?filter=author.id:A4347368963
#
# E. Rodney Canfield | University of Georgia
# https://api.openalex.org/authors?search=E. Rodney Canfield&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Walter Potter | University of Georgia
# https://api.openalex.org/authors?search=Walter Potter&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Robert W. Robinson | University of Georgia
# https://api.openalex.org/authors?search=Robert W. Robinson&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Robert W. Robinson | https://openalex.org/I165733156 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A4350154046
#
# Jeffrey W. Smith | University of Georgia
# https://api.openalex.org/authors?search=Jeffrey W. Smith&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Kang Li | University of Georgia
# https://api.openalex.org/authors?search=Kang Li&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Kang Li | https://openalex.org/I165733156 | 1
# find!
# https://api.openalex.org/works?filter=author.id:A2974076763
#
# Hanchuan Peng | University of Georgia
# https://api.openalex.org/authors?search=Hanchuan Peng&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Amit P. Sheth | University of Georgia
# https://api.openalex.org/authors?search=Amit P. Sheth&filter=last_known_institution.id:https://openalex.org/I165733156&select=id,display_name,last_known_institution,works_api_url&per-page=200
#
# Nina Amenta | University of California--Davis
#
# Zhaojun Bai | University of California--Davis
#
# Matt Bishop | University of California--Davis
#
# Hao Chen | University of California--Davis
#
# Raissa M. D #039;Souza | University of California--Davis
#
# Ian Davidson | University of California--Davis
#
# Prem Devanbu | University of California--Davis
#
# David Doty | University of California--Davis
#
# Kurt Eiselt | University of California--Davis
#
# Matthew Farrens | University of California--Davis
#
# Vladimir Filkov | University of California--Davis
#
# Matt Franklin | University of California--Davis
#
# Dipak Ghosal | University of California--Davis
#
# Francois Gygi | University of California--Davis
#
# Bernd Hamann | University of California--Davis
#
# Sam King | University of California--Davis
#
# Patrice Koehl | University of California--Davis
#
# Xin Liu | University of California--Davis
#
# Jason Lowe-Power | University of California--Davis
#
# Kwan-Liu Ma | University of California--Davis
#
# Norman Matloff | University of California--Davis
#
# Joshua McCoy | University of California--Davis
#
# Prasant Mohapatra | University of California--Davis
#
# Michael Neff | University of California--Davis
#
# Christopher Nitta | University of California--Davis
#
# Randall O\xe2\x80\x99Reilly | University of California--Davis
#
# Julian Panetta | University of California--Davis
#
# Jo\xc3\xabl Porquet-Lupine | University of California--Davis
#
# Phillip Rogaway | University of California--Davis
#
# Cindy Rubio Gonz\xc3\xa1lez | University of California--Davis
#
# Mohammad Sadoghi | University of California--Davis
#
# Zubair Shafiq | University of California--Davis
#
# Ilias Tagkopoulos | University of California--Davis
#
# Aditya Thakur | University of California--Davis
#
# Hao-Chuan Wang | University of California--Davis
#
# S. Felix Wu | University of California--Davis
#
# Zhou Yu | University of California--Davis
#
# Sean Peisert | University of California--Davis
#
# Massimo Tornatore | University of California--Davis
#
# Gunther Weber | University of California--Davis
#
# Venkatesh Akella | University of California--Davis
#
# Nicholas Anderson | University of California--Davis
#
# Sharon Aviran | University of California--Davis
#
# Hemant Bhargava | University of California--Davis
#
# C. Titus Brown | University of California--Davis
#
# Harry H. Cheng | University of California--Davis
#
# R. Holland Cheng | University of California--Davis
#
# Chen-Nee Chuah | University of California--Davis
#
# James P. Crutchfield | University of California--Davis
#
# Jesus De Loera | University of California--Davis
#
# Jonathan A. Eisen | University of California--Davis
#
# Robert Faris | University of California--Davis
#
# Seth Frey | University of California--Davis
#
# Soheil Ghiasi | University of California--Davis
#
# Martin Hilbert | University of California--Davis
#
# Michael Hogarth | University of California--Davis
#
# Fereydoun Hormozdiari | University of California--Davis
#
# Sanjay Joshi | University of California--Davis
#
# Matthias Koeppe | University of California--Davis
#
# Greg Kuperberg | University of California--Davis
#
# Pantelis Loupos | University of California--Davis
#
# Laura Marcu | University of California--Davis
#
# Debbie Niemeier | University of California--Davis
#
# Michael Oskin | University of California--Davis
#
# John D. Owens | University of California--Davis
#
# Gregory B. Pasternack | University of California--Davis
#
# Gerald Quon | University of California--Davis
#
# Luis Rademacher | University of California--Davis
#
# Bahram Ravani | University of California--Davis
#
# G. Robert Redinbo | University of California--Davis
#
# David Rocke | University of California--Davis
#
# Kenji Sagae | University of California--Davis
#
# Jeffrey Schank | University of California--Davis
#
# Kenneth Shackel | University of California--Davis
#
# Prabhu Shankar | University of California--Davis
#
# David Slaughter | University of California--Davis
#
# Mairaj Syed | University of California--Davis
#
# Susan L. Ustin | University of California--Davis
#
# Katia Vega | University of California--Davis
#
# John S. Werner | University of California--Davis
#
# Kent D. Wilken | University of California--Davis
#
# Catherine Yang | University of California--Davis
#
# S.J. Ben Yoo | University of California--Davis
#
# David H. Bailey | University of California--Davis
#
# Silvia Crivelli | University of California--Davis
#
# Amit Pande | University of California--Davis
#
# Matt Butner | University of California--Davis
#
# Sean Davis | University of California--Davis
#
# Yelena Frid | University of California--Davis
#
# John Bruno | University of California--Davis
#
# Dan Gusfield | University of California--Davis
#
# Kenneth Joy | University of California--Davis
#
# Lawrence Kou | University of California--Davis
#
# Karl Levitt | University of California--Davis
#
# Peter Linz | University of California--Davis
#
# Charles  quot;Chip quot; Martel | University of California--Davis
#
# Nelson Max | University of California--Davis
#
# Biswanath Mukherjee | University of California--Davis
#
# Ron Olsson | University of California--Davis
#
# Raju Pandey | University of California--Davis
#
# Richard Walters | University of California--Davis
#
# Jeffery Adams | University of California--Davis
#
# Alyssa Bates | University of California--Davis
#
# Sara Chilimidos | University of California--Davis
#
# Octavio Alexander Corona | University of California--Davis
#
# Anatoli Fedorenko | University of California--Davis
#
# Ken Gribble | University of California--Davis
#
# Noreen Johnson | University of California--Davis
#
# Meshell Louderman | University of California--Davis
#
# Melinda Meeker | University of California--Davis
#
# Jim Moersfelder | University of California--Davis
#
# Cassady Ogedegbe | University of California--Davis
#
# Rachael Rubinato | University of California--Davis
#
# Jane Ryan | University of California--Davis
#
# Jason Sison | University of California--Davis
#
# Jessica Stoller | University of California--Davis
#
# Ryan Adams | Princeton University
# https://api.openalex.org/authors?search=Ryan Adams&filter=last_known_institution.id:https://openalex.org/I20089843&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Ryan Adams | https://openalex.org/I20089843 | 36
# find!
# https://api.openalex.org/works?filter=author.id:A4355737697
#
# Andrew Appel | Princeton University
# https://api.openalex.org/authors?search=Andrew Appel&filter=last_known_institution.id:https://openalex.org/I20089843&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Andrew Appel | https://openalex.org/I20089843 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A4359262918
#
# Sanjeev Arora | Princeton University
# https://api.openalex.org/authors?search=Sanjeev Arora&filter=last_known_institution.id:https://openalex.org/I20089843&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Sanjeev Arora | https://openalex.org/I20089843 | 8
# find!
# https://api.openalex.org/works?filter=author.id:A2159007752
#
# David August | Princeton University
# https://api.openalex.org/authors?search=David August&filter=last_known_institution.id:https://openalex.org/I20089843&select=id,display_name,last_known_institution,works_api_url&per-page=200
# David August | https://openalex.org/I20089843 | 4
# find!
# https://api.openalex.org/works?filter=author.id:A2185216079
#
# Jack Brassil | Princeton University
# https://api.openalex.org/authors?search=Jack Brassil&filter=last_known_institution.id:https://openalex.org/I20089843&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Jack Brassil | https://openalex.org/I20089843 | 7
# find!
# https://api.openalex.org/works?filter=author.id:A4342449315
#
# Mark Braverman | Princeton University
# https://api.openalex.org/authors?search=Mark Braverman&filter=last_known_institution.id:https://openalex.org/I20089843&select=id,display_name,last_known_institution,works_api_url&per-page=200
# Mark Braverman | https://openalex.org/I20089843 | 5
# find!
# https://api.openalex.org/works?filter=author.id:A4342232316
#
# Bernard Chazelle | Princeton University
# https://api.openalex.org/authors?search=Bernard Chazelle&filter=last_known_institution.id:https://openalex.org/I20089843&select=id,display_name,last_known_institution,works_api_url&per-page=200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16468\4218998429.py in <module>
#      16             print(url)
#      17
# ---> 18             page_with_results = requests.get(url).json()
#      19             # loop through partial list of results
#      20             results = page_with_results['results']
#
# D:\Software\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# D:\Software\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# D:\Software\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# D:\Software\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# D:\Software\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# D:\Software\Anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\Software\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# D:\Software\Anaconda\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# D:\Software\Anaconda\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# D:\Software\Anaconda\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# D:\Software\Anaconda\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# D:\Software\Anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# D:\Software\Anaconda\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
not_found
# Out:
#                author              institution
# 0       Agouris,Peggy  College of William Mary
# 1      Chaparro,Oscar  College of William Mary
# 2           Davis,Tim  College of William Mary
# 3      Deverick,James  College of William Mary
# 4   Evtyushkin,Dmitry  College of William Mary
# ..                ...                      ...
# 80             Hao Wu         Emory University
# 81           Li Xiong         Emory University
# 82          Carl Yang         Emory University
# 83         Tianwei Yu         Emory University
# 84         Liang Zhao         Emory University
#
# [85 rows x 2 columns]

# %%
whole_info
# Out:
#                author                      institution  \
# 0      Chaparro,Oscar   https://openalex.org/I16285277
# 1      Deverick,James   https://openalex.org/I16285277
# 2   Evtyushkin,Dmitry   https://openalex.org/I16285277
# 3          Hu,Tianran   https://openalex.org/I16285277
# 4          Jog,Adwait   https://openalex.org/I16285277
# ..                ...                              ...
# 61      Avani Wildani  https://openalex.org/I150468666
# 62             Hao Wu  https://openalex.org/I150468666
# 63           Li Xiong  https://openalex.org/I150468666
# 64          Carl Yang  https://openalex.org/I150468666
# 65         Liang Zhao  https://openalex.org/I150468666
#
#                                             works_url
# 0   https://api.openalex.org/works?filter=author.i...
# 1   https://api.openalex.org/works?filter=author.i...
# 2   https://api.openalex.org/works?filter=author.i...
# 3   https://api.openalex.org/works?filter=author.i...
# 4   https://api.openalex.org/works?filter=author.i...
# ..                                                ...
# 61  https://api.openalex.org/works?filter=author.i...
# 62  https://api.openalex.org/works?filter=author.i...
# 63  https://api.openalex.org/works?filter=author.i...
# 64  https://api.openalex.org/works?filter=author.i...
# 65  https://api.openalex.org/works?filter=author.i...
#
# [66 rows x 3 columns]

# %%
whole_info.to_csv('whole_info.csv', index=False)
print(total_cnt)
print(find_cnt)

# %%
# use "work_url" to find the certain publication
works_url_with_page = '{}&select=id,doi,title,publication_date&page={}&per-page=200'
publication_set = set()

# use to crate relation between "faculty" and "publication" node in Neo4j
author_works = {}
# use to crate relation between "faculty" and "institution" node in Neo4j
author_institution = pd.DataFrame(columns=['author_id', 'institution_id'])

# information of "publication" node in Neo4j
publication_info = pd.DataFrame(columns=['id', 'doi', 'title', 'publication_date'])
# information of "faculty" node in Neo4j
author_info = pd.DataFrame(columns=['id', 'name', 'works_count'])

output_file = "find_work_info.txt"
with open(output_file, 'w') as file:
    for index, row in whole_info.iterrows():
        works_url = row['works_url']
        author = works_url.split(':')[-1]

        new_row = {'author_id': works_url.split(':')[-1], 'institution_id': row['institution']}
        # store relation between "faculty" and "institution" node
        author_institution = pd.concat([author_institution, pd.DataFrame([new_row])], ignore_index=True)

        file.write(author+"\n"+ works_url+"\n")
        print(author+"\n"+ works_url)
        page = 1
        has_more_pages = True
        work_count = 0
        # loop through pages
        while has_more_pages:

            # set page value and request page from OpenAlex
            url = works_url_with_page.format(works_url,page)
            print(url)
            file.write(url+"\n")
            page_with_results = requests.get(url).json()
            work_count = page_with_results['meta']['count']

            # loop through partial list of results
            results = page_with_results['results']
            if len(results) > 0:
                author_works[author] = []
            # flag = False
            for i,res in enumerate(results):
                my_id = res['id']
                # store relation between "faculty" and "publication" node in Neo4j
                author_works[author].append(my_id)
                if my_id not in publication_set:
                    publication_set.add(my_id)
                    new_row = {'id': res['id'], 'doi': res['doi'], 'title': res['title'], 'publication_date': res['publication_date']}
                    # store publication info
                    publication_info = pd.concat([publication_info, pd.DataFrame([new_row])], ignore_index=True)

            # next page
            page += 1
            per_page = page_with_results['meta']['per_page']
            has_more_pages = len(results) == per_page
        print()
        file.write("\n")
        new_row = {'id': author, 'name': row['author'], 'works_count': work_count}
        author_info = pd.concat([author_info, pd.DataFrame([new_row])], ignore_index=True)

publication_info.to_csv('publication_info.csv', index=False)
author_info.to_csv('author_info.csv', index=False)
author_institution.to_csv('author_institution.csv', index=False)
# Out:
# A4318812603
# https://api.openalex.org/works?filter=author.id:A4318812603
# https://api.openalex.org/works?filter=author.id:A4318812603&select=id,doi,title,publication_date&page=1
#
# A2288689954
# https://api.openalex.org/works?filter=author.id:A2288689954
# https://api.openalex.org/works?filter=author.id:A2288689954&select=id,doi,title,publication_date&page=1
#
# A253140105
# https://api.openalex.org/works?filter=author.id:A253140105
# https://api.openalex.org/works?filter=author.id:A253140105&select=id,doi,title,publication_date&page=1
#
# A4343533280
# https://api.openalex.org/works?filter=author.id:A4343533280
# https://api.openalex.org/works?filter=author.id:A4343533280&select=id,doi,title,publication_date&page=1
# https://api.openalex.org/works?filter=author.id:A4343533280&select=id,doi,title,publication_date&page=2
#
# A2006476705
# https://api.openalex.org/works?filter=author.id:A2006476705
# https://api.openalex.org/works?filter=author.id:A2006476705&select=id,doi,title,publication_date&page=1
# https://api.openalex.org/works?filter=author.id:A2006476705&select=id,doi,title,publication_date&page=2
# https://api.openalex.org/works?filter=author.id:A2006476705&select=id,doi,title,publication_date&page=3
#
# A4340429096
# https://api.openalex.org/works?filter=author.id:A4340429096
# https://api.openalex.org/works?filter=author.id:A4340429096&select=id,doi,title,publication_date&page=1
# https://api.openalex.org/works?filter=author.id:A4340429096&select=id,doi,title,publication_date&page=2
# https://api.openalex.org/works?filter=author.id:A4340429096&select=id,doi,title,publication_date&page=3
# https://api.openalex.org/works?filter=author.id:A4340429096&select=id,doi,title,publication_date&page=4
# https://api.openalex.org/works?filter=author.id:A4340429096&select=id,doi,title,publication_date&page=5
# https://api.openalex.org/works?filter=author.id:A4340429096&select=id,doi,title,publication_date&page=6
# https://api.openalex.org/works?filter=author.id:A4340429096&select=id,doi,title,publication_date&page=7
#
# A4353664840
# https://api.openalex.org/works?filter=author.id:A4353664840
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=1
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=2
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=3
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=4
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=5
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=6
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=7
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=8
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=9
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=10
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=11
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=12
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=13
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=14
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=15
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=16
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=17
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=18
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=19
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=20
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=21
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=22
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=23
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=24
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=25
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=26
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=27
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=28
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=29
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=30
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=31
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=32
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=33
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=34
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=35
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=36
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=37
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=38
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=39
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=40
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=41
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=42
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=43
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=44
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=45
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=46
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=47
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=48
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=49
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=50
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=51
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=52
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=53
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=54
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=55
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=56
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=57
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=58
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=59
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=60
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=61
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=62
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=63
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=64
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=65
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=66
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=67
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=68
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=69
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=70
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=71
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=72
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=73
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=74
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=75
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=76
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=77
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=78
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=79
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=80
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=81
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=82
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=83
# https://api.openalex.org/works?filter=author.id:A4353664840&select=id,doi,title,publication_date&page=84
#
# A2148437070
# https://api.openalex.org/works?filter=author.id:A2148437070
# https://api.openalex.org/works?filter=author.id:A2148437070&select=id,doi,title,publication_date&page=1
#
# A2168303293
# https://api.openalex.org/works?filter=author.id:A2168303293
# https://api.openalex.org/works?filter=author.id:A2168303293&select=id,doi,title,publication_date&page=1
# https://api.openalex.org/works?filter=author.id:A2168303293&select=id,doi,title,publication_date&page=2
# https://api.openalex.org/works?filter=author.id:A2168303293&select=id,doi,title,publication_date&page=3
#
# A4308409409
# https://api.openalex.org/works?filter=author.id:A4308409409
# https://api.openalex.org/works?filter=author.id:A4308409409&select=id,doi,title,publication_date&page=1
#
# A4351470416
# https://api.openalex.org/works?filter=author.id:A4351470416
# https://api.openalex.org/works?filter=author.id:A4351470416&select=id,doi,title,publication_date&page=1
# https://api.openalex.org/works?filter=author.id:A4351470416&select=id,doi,title,publication_date&page=2
# https://api.openalex.org/works?filter=author.id:A4351470416&select=id,doi,title,publication_date&page=3
# https://api.openalex.org/works?filter=author.id:A4351470416&select=id,doi,title,publication_date&page=4
#
# A67342874
# https://api.openalex.org/works?filter=author.id:A67342874
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=1
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=2
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=3
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=4
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=5
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=6
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=7
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=8
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=9
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=10
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=11
# https://api.openalex.org/works?filter=author.id:A67342874&select=id,doi,title,publication_date&page=12

# %%
# load into csv file
csv_file_path = 'author_works.csv'
with open(csv_file_path, 'w', newline='') as file:
    writer = csv.writer(file)
    for key, value in author_works.items():
        for work in value:
            writer.writerow([key, work])

print("create：", csv_file_path)
# Out:
# CSV文件已创建： author_works.csv

# %%
# # 处理institution数据
# df_institution = pd.DataFrame(columns=['id', 'name', 'photoUrl'])
#
# for element in data:
#     institution = element['affiliation']
#     new_row = {'id': institution['id'], 'name': institution['name'], 'photoUrl': institution['photoUrl']}
#     if new_row['id'] not in df_institution['id'].values:
#         df_institution = pd.concat([df_institution, pd.DataFrame([new_row])], ignore_index=True)
#
# # df_institution.to_csv('institution.csv', index=False)
# df_institution

# %%
# # 处理faculty数据
# df_faculty = pd.DataFrame(columns=['id', 'name', 'position', 'researchInterest', 'email', 'phone', ])
#
# for element in data:
#     institution = element['affiliation']
#     new_row = {'id': institution['id'], 'name': institution['name'], 'photoUrl': institution['photoUrl']}
#     if new_row['id'] not in df_institution['id'].values:
#         df_institution = pd.concat([df_institution, pd.DataFrame([new_row])], ignore_index=True)
#
# df_institution.to_csv('institution.csv', index=False)
# df_institution

# %%
cnt_total = 0
cnt_find_name = 0
cnt_find_institution = 0
is_find_semantic = []

# %%
import csv
import requests

author_url_with_page = 'https://api.semanticscholar.org/graph/v1/author/search?query={}&fields=name,affiliations'

with open('faculty.csv', 'r') as file:
    csv_reader = csv.reader(file)


# output_file = "find_semantic_info.txt"
# with open(output_file, 'a') as file:
    for row in csv_reader:
        author = row[0]
        institution = row[1]

        if author in is_find_semantic:
            print("continue")
            continue

        print(author+" "+ institution)
        cnt_total = cnt_total + 1

        # set page value and request page from OpenAlex
        url = author_url_with_page.format(author)
        print(url)

        page_with_results = requests.get(url).json()

        # loop through partial list of results
        results = page_with_results['data']
        is_find_semantic.append(author)
        if len(results)>0:
            cnt_find_name = cnt_find_name + 1
        # flag = False
        for i,res in enumerate(results):
            if 'affiliations' in res:
                if len(res['affiliations']) > 0:
                    cnt_find_institution = cnt_find_institution + 1
                    break

    print("totally find: " + str(cnt_total))
    print("find: " + str(cnt_find_name))
    print("faculty with affiliation: " + str(cnt_find_institution))
# Out:
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# continue
# Stephen Wicker Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=Stephen Wicker&fields=name,affiliations
# Amy Williams Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=Amy Williams&fields=name,affiliations
# David Williamson Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=David Williamson&fields=name,affiliations
# Christina Lee Yu Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=Christina Lee Yu&fields=name,affiliations
# Haiyuan Yu Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=Haiyuan Yu&fields=name,affiliations
# Ramin Zabih Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ramin Zabih&fields=name,affiliations
# Cheng Zhang Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=Cheng Zhang&fields=name,affiliations
# Zhiru Zhang Cornell University
# https://api.semanticscholar.org/graph/v1/author/search?query=Zhiru Zhang&fields=name,affiliations
# Venkataramanan "Ragu" Balakrishnan Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Venkataramanan "Ragu" Balakrishnan&fields=name,affiliations
# Marc Buchner Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Marc Buchner&fields=name,affiliations
# M. Cenk Cavusoglu Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=M. Cenk Cavusoglu&fields=name,affiliations
# Vira Chankong Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Vira Chankong&fields=name,affiliations
# Michael Fu Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael Fu&fields=name,affiliations
# Mario Garcia-Sanz Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mario Garcia-Sanz&fields=name,affiliations
# Evren Gurkan Cavusoglu Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Evren Gurkan Cavusoglu&fields=name,affiliations
# Ming-Chun Huang Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ming-Chun Huang&fields=name,affiliations
# Hossein Lavasani Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Hossein Lavasani&fields=name,affiliations
# Greg Lee Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Greg Lee&fields=name,affiliations
# Pan Li Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Pan Li&fields=name,affiliations
# Wei Lin Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Wei Lin&fields=name,affiliations
# Kenneth Loparo Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Kenneth Loparo&fields=name,affiliations
# Behnam Malakooti Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Behnam Malakooti&fields=name,affiliations
# Mehran Mehregany Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mehran Mehregany&fields=name,affiliations
# Pedram Mohseni Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Pedram Mohseni&fields=name,affiliations
# Wyatt Newman Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Wyatt Newman&fields=name,affiliations
# Chris Papachristou Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Chris Papachristou&fields=name,affiliations
# Daniel Saab Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Daniel Saab&fields=name,affiliations
# Sree Sreenath Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Sree Sreenath&fields=name,affiliations
# Chris Zorman Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Chris Zorman&fields=name,affiliations
# Cynthia Hatcher Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Cynthia Hatcher&fields=name,affiliations
# Lavanya Kalahasti Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Lavanya Kalahasti&fields=name,affiliations
# Elliot Korth Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Elliot Korth&fields=name,affiliations
# Laura Kuhar Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Laura Kuhar&fields=name,affiliations
# Salvatore Russo Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Salvatore Russo&fields=name,affiliations
# Heather Smith Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Heather Smith&fields=name,affiliations
# YoLonda Stiggers Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=YoLonda Stiggers&fields=name,affiliations
# Ryan Watson Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ryan Watson&fields=name,affiliations
# Mahdi Bayat Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mahdi Bayat&fields=name,affiliations
# Farhad Kaffashi Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Farhad Kaffashi&fields=name,affiliations
# Soumyajit Mandal Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Soumyajit Mandal&fields=name,affiliations
# George Ernst Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=George Ernst&fields=name,affiliations
# Sheldon Gruber Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Sheldon Gruber&fields=name,affiliations
# Frank Merat Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Frank Merat&fields=name,affiliations
# Lee White Case Western Reserve University
# https://api.semanticscholar.org/graph/v1/author/search?query=Lee White&fields=name,affiliations
# Dana Angluin Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Dana Angluin&fields=name,affiliations
# James Aspnes Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=James Aspnes&fields=name,affiliations
# Abhishek Bhattacharjee Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Abhishek Bhattacharjee&fields=name,affiliations
# Yang Cai Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Yang Cai&fields=name,affiliations
# Julie Dorsey Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Julie Dorsey&fields=name,affiliations
# Stanley Eisenstat Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Stanley Eisenstat&fields=name,affiliations
# Joan Feigenbaum Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Joan Feigenbaum&fields=name,affiliations
# Michael Fischer Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael Fischer&fields=name,affiliations
# David Gelernter Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=David Gelernter&fields=name,affiliations
# Anurag Khandelwal Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Anurag Khandelwal&fields=name,affiliations
# Theodore Kim Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Theodore Kim&fields=name,affiliations
# Ruzica Piskac Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ruzica Piskac&fields=name,affiliations
# Dragomir Radev Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Dragomir Radev&fields=name,affiliations
# Vladimir Rokhlin Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Vladimir Rokhlin&fields=name,affiliations
# Holly Rushmeier Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Holly Rushmeier&fields=name,affiliations
# Brian Scassellati Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Brian Scassellati&fields=name,affiliations
# Zhong Shao Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Zhong Shao&fields=name,affiliations
# Abraham Silberschatz Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Abraham Silberschatz&fields=name,affiliations
# Robert Soul\xc3\xa9 Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Robert Soul\xc3\xa9&fields=name,affiliations
# Daniel Spielman Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Daniel Spielman&fields=name,affiliations
# Marynel V\xc3\xa1zquez Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Marynel V\xc3\xa1zquez&fields=name,affiliations
# Nisheeth Vishnoi Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Nisheeth Vishnoi&fields=name,affiliations
# Y. Richard Yang Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Y. Richard Yang&fields=name,affiliations
# Lin Zhong Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Lin Zhong&fields=name,affiliations
# Steven Zucker Yale University
# https://api.semanticscholar.org/graph/v1/author/search?query=Steven Zucker&fields=name,affiliations
# Yair Amir Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Yair Amir&fields=name,affiliations
# Raman Arora Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Raman Arora&fields=name,affiliations
# Vladimir Braverman Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Vladimir Braverman&fields=name,affiliations
# Randal Burns Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Randal Burns&fields=name,affiliations
# Yinzhi Cao Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Yinzhi Cao&fields=name,affiliations
# Anton Dahbura Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Anton Dahbura&fields=name,affiliations
# Ali Darvish Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ali Darvish&fields=name,affiliations
# Michael Dinitz Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael Dinitz&fields=name,affiliations
# Mark Dredze Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mark Dredze&fields=name,affiliations
# Kevin Duh Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Kevin Duh&fields=name,affiliations
# Jason Eisner Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jason Eisner&fields=name,affiliations
# Soudeh Ghorbani Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Soudeh Ghorbani&fields=name,affiliations
# Matthew D. Green Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Matthew D. Green&fields=name,affiliations
# Gregory D. Hager Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Gregory D. Hager&fields=name,affiliations
# Susan Hohenberger Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Susan Hohenberger&fields=name,affiliations
# David Hovemeyer Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=David Hovemeyer&fields=name,affiliations
# Chien-Ming Huang Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Chien-Ming Huang&fields=name,affiliations
# Ryan (Peng) Huang Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ryan (Peng) Huang&fields=name,affiliations
# Abhishek Jain Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Abhishek Jain&fields=name,affiliations
# Xin Jin Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Xin Jin&fields=name,affiliations
# Peter Kazanzides Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Peter Kazanzides&fields=name,affiliations
# Michael Kazhdan Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael Kazhdan&fields=name,affiliations
# Philipp Koehn Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Philipp Koehn&fields=name,affiliations
# S. Rao Kosaraju Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=S. Rao Kosaraju&fields=name,affiliations
# Benjamin Langmead Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Benjamin Langmead&fields=name,affiliations
# Xin Li Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Xin Li&fields=name,affiliations
# Ali Madooei Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ali Madooei&fields=name,affiliations
# Sara Miner More Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Sara Miner More&fields=name,affiliations
# Nassir Navab Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Nassir Navab&fields=name,affiliations
# Matt Post Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Matt Post&fields=name,affiliations
# Aviel Rubin Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Aviel Rubin&fields=name,affiliations
# Steven Salzberg Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Steven Salzberg&fields=name,affiliations
# Suchi Saria Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Suchi Saria&fields=name,affiliations
# Michael Schatz Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael Schatz&fields=name,affiliations
# Joao Sedoc Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Joao Sedoc&fields=name,affiliations
# Joanne Selinski Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Joanne Selinski&fields=name,affiliations
# Wei Shen Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Wei Shen&fields=name,affiliations
# Ilya Shpitser Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ilya Shpitser&fields=name,affiliations
# Scott Smith Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Scott Smith&fields=name,affiliations
# Alex Szalay Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Alex Szalay&fields=name,affiliations
# Russell H. Taylor Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Russell H. Taylor&fields=name,affiliations
# Mathias Unberath Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mathias Unberath&fields=name,affiliations
# Benjamin Van Durme Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Benjamin Van Durme&fields=name,affiliations
# David Yarowsky Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=David Yarowsky&fields=name,affiliations
# Alan Yuille Johns Hopkins University
# https://api.semanticscholar.org/graph/v1/author/search?query=Alan Yuille&fields=name,affiliations
# Omid Abari University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Omid Abari&fields=name,affiliations
# Kai-Wei Chang University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Kai-Wei Chang&fields=name,affiliations
# Junghoo (John) Cho University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Junghoo (John) Cho&fields=name,affiliations
# Jason (Jingsheng) Cong University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Jason (Jingsheng) Cong&fields=name,affiliations
# Adnan Darwiche University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Adnan Darwiche&fields=name,affiliations
# Joseph DiStefano University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Joseph DiStefano&fields=name,affiliations
# Paul Eggert University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Paul Eggert&fields=name,affiliations
# Eleazar Eskin University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Eleazar Eskin&fields=name,affiliations
# Eliezer Gafni University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Eliezer Gafni&fields=name,affiliations
# Quanquan Gu University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Quanquan Gu&fields=name,affiliations
# Eran Halperin University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Eran Halperin&fields=name,affiliations
# Cho-Jui Hsieh University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Cho-Jui Hsieh&fields=name,affiliations
# Miryung Kim University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Miryung Kim&fields=name,affiliations
# Richard Korf University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Richard Korf&fields=name,affiliations
# Songwu Lu University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Songwu Lu&fields=name,affiliations
# Raghu Meka University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Raghu Meka&fields=name,affiliations
# Todd Millstein University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Todd Millstein&fields=name,affiliations
# Baharan Mirzasoleiman University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Baharan Mirzasoleiman&fields=name,affiliations
# Ravi Netravali University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Ravi Netravali&fields=name,affiliations
# Tony Nowatzki University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Tony Nowatzki&fields=name,affiliations
# Rafail Ostrovsky University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Rafail Ostrovsky&fields=name,affiliations
# Jens Palsberg University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Jens Palsberg&fields=name,affiliations
# Nanyun Peng University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Nanyun Peng&fields=name,affiliations
# Miodrag Potkonjak University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Miodrag Potkonjak&fields=name,affiliations
# Glenn Reinman University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Glenn Reinman&fields=name,affiliations
# Amit Sahai University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Amit Sahai&fields=name,affiliations
# Sriram Sankararaman University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Sriram Sankararaman&fields=name,affiliations
# Majid Sarrafzadeh University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Majid Sarrafzadeh&fields=name,affiliations
# Alexander Sherstov University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Alexander Sherstov&fields=name,affiliations
# David Smallberg University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=David Smallberg&fields=name,affiliations
# Stefano Soatto University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Stefano Soatto&fields=name,affiliations
# Yizhou Sun University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Yizhou Sun&fields=name,affiliations
# Yuval Tamir University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Yuval Tamir&fields=name,affiliations
# Demetri Terzopoulos University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Demetri Terzopoulos&fields=name,affiliations
# Guy Van den Broeck University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Guy Van den Broeck&fields=name,affiliations
# George Varghese University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=George Varghese&fields=name,affiliations
# Wei Wang University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Wei Wang&fields=name,affiliations
# Harry Xu University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Harry Xu&fields=name,affiliations
# Lixia Zhang University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Lixia Zhang&fields=name,affiliations
# Algirdas Avizienis University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Algirdas Avizienis&fields=name,affiliations
# Rajive Bagrodia University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Rajive Bagrodia&fields=name,affiliations
# Alfonso F. Cardenas University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Alfonso F. Cardenas&fields=name,affiliations
# Jack Carlyle University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Jack Carlyle&fields=name,affiliations
# Wesley Chu University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Wesley Chu&fields=name,affiliations
# Michael G. Dyer University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael G. Dyer&fields=name,affiliations
# Milos D. Ercegovac University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Milos D. Ercegovac&fields=name,affiliations
# Sheila Greibach University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Sheila Greibach&fields=name,affiliations
# Leonard Kleinrock University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Leonard Kleinrock&fields=name,affiliations
# Allen Klinger University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Allen Klinger&fields=name,affiliations
# Lawrence P. McNamee University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Lawrence P. McNamee&fields=name,affiliations
# Richard R. Muntz University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Richard R. Muntz&fields=name,affiliations
# D. Stott Parker University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=D. Stott Parker&fields=name,affiliations
# Judea Pearl University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Judea Pearl&fields=name,affiliations
# David A. Rennels University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=David A. Rennels&fields=name,affiliations
# Carlo Zaniolo University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Carlo Zaniolo&fields=name,affiliations
# Alex Afanasyev University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Alex Afanasyev&fields=name,affiliations
# David Heckerman University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=David Heckerman&fields=name,affiliations
# Van Jacobson University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Van Jacobson&fields=name,affiliations
# Alan Kay University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Alan Kay&fields=name,affiliations
# Carey Nachenberg University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Carey Nachenberg&fields=name,affiliations
# Giovanni Pau University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Giovanni Pau&fields=name,affiliations
# Ramin Ramezani University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Ramin Ramezani&fields=name,affiliations
# Peter Reiher University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Peter Reiher&fields=name,affiliations
# Jason Ernst University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Jason Ernst&fields=name,affiliations
# Alyson Fletcher University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Alyson Fletcher&fields=name,affiliations
# Stanley Osher University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Stanley Osher&fields=name,affiliations
# Fabien Scalzo University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Fabien Scalzo&fields=name,affiliations
# Mani Srivastava University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Mani Srivastava&fields=name,affiliations
# Mihaela van der Schaar University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Mihaela van der Schaar&fields=name,affiliations
# Song Chun Zhu University of California--Los Angeles
# https://api.semanticscholar.org/graph/v1/author/search?query=Song Chun Zhu&fields=name,affiliations
# Tarek Abdelzaher University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Tarek Abdelzaher&fields=name,affiliations
# Sarita V. Adve University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Sarita V. Adve&fields=name,affiliations
# Vikram Adve University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Vikram Adve&fields=name,affiliations
# Gul A. Agha University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Gul A. Agha&fields=name,affiliations
# Abdussalam Alawini University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Abdussalam Alawini&fields=name,affiliations
# Haitham Al-Hassanieh University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Haitham Al-Hassanieh&fields=name,affiliations
# Gabrielle Dawn Allen University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Gabrielle Dawn Allen&fields=name,affiliations
# Nancy M. Amato University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Nancy M. Amato&fields=name,affiliations
# Mark A. Anastasio University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Mark A. Anastasio&fields=name,affiliations
# Lawrence Angrave University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Lawrence Angrave&fields=name,affiliations
# Brian P. Bailey University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Brian P. Bailey&fields=name,affiliations
# Michael Bailey University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael Bailey&fields=name,affiliations
# Adam Bates University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Adam Bates&fields=name,affiliations
# Mattox Alan Beckman University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Mattox Alan Beckman&fields=name,affiliations
# Catherine Lesley Blake University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Catherine Lesley Blake&fields=name,affiliations
# Nikita Borisov University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Nikita Borisov&fields=name,affiliations
# Timothy Bretl University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Timothy Bretl&fields=name,affiliations
# Robert J. Brunner University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Robert J. Brunner&fields=name,affiliations
# Matthew Caesar University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Matthew Caesar&fields=name,affiliations
# Roy H. Campbell University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Roy H. Campbell&fields=name,affiliations
# George Chacko University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=George Chacko&fields=name,affiliations
# Geoffrey Werner Challen University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Geoffrey Werner Challen&fields=name,affiliations
# Timothy Moon-Yew Chan University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Timothy Moon-Yew Chan&fields=name,affiliations
# Karthekeyan Chandrasekaran University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Karthekeyan Chandrasekaran&fields=name,affiliations
# Eshwar Chandrasekharan University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Eshwar Chandrasekharan&fields=name,affiliations
# Kevin Chenchuan Chang University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Kevin Chenchuan Chang&fields=name,affiliations
# Chandra Sekhar Chekuri University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Chandra Sekhar Chekuri&fields=name,affiliations
# Deming Chen University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Deming Chen&fields=name,affiliations
# Girish Chowdhary University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Girish Chowdhary&fields=name,affiliations
# Benjamin Cosman University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Benjamin Cosman&fields=name,affiliations
# Donna J. Cox University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Donna J. Cox&fields=name,affiliations
# Ryan Matthew Cunningham University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Ryan Matthew Cunningham&fields=name,affiliations
# Neal E. Davis University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Neal E. Davis&fields=name,affiliations
# Gerald F. DeJong, II University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Gerald F. DeJong, II&fields=name,affiliations
# Payam Delgosha University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Payam Delgosha&fields=name,affiliations
# Jana Diesner University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Jana Diesner&fields=name,affiliations
# Minh N. Do University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Minh N. Do&fields=name,affiliations
# Katherine Rose Driggs-Campbell University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Katherine Rose Driggs-Campbell&fields=name,affiliations
# Geir E. Dullerud University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Geir E. Dullerud&fields=name,affiliations
# Mohammed El-Kebir University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Mohammed El-Kebir&fields=name,affiliations
# Jeff G. Erickson University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Jeff G. Erickson&fields=name,affiliations
# Carl Evans University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Carl Evans&fields=name,affiliations
# Wade A. Fagen-Ulmschneider University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Wade A. Fagen-Ulmschneider&fields=name,affiliations
# Paul Fischer University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Paul Fischer&fields=name,affiliations
# Margaret M. Fleck University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Margaret M. Fleck&fields=name,affiliations
# Christopher Wardlaw Fletcher University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Christopher Wardlaw Fletcher&fields=name,affiliations
# Michael A. Forbes University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael A. Forbes&fields=name,affiliations
# David Forsyth University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=David Forsyth&fields=name,affiliations
# H. George Friedman University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=H. George Friedman&fields=name,affiliations
# Jugal Garg University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Jugal Garg&fields=name,affiliations
# Charles Gear University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Charles Gear&fields=name,affiliations
# Yael Gertner University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Yael Gertner&fields=name,affiliations
# Saugata Ghose University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Saugata Ghose&fields=name,affiliations
# Roxana Girju University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Roxana Girju&fields=name,affiliations
# Philip B. Godfrey University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Philip B. Godfrey&fields=name,affiliations
# Mani Golparvar Fard University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Mani Golparvar Fard&fields=name,affiliations
# William D. Gropp University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=William D. Gropp&fields=name,affiliations
# Liangyan Gui University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Liangyan Gui&fields=name,affiliations
# Carl Gunter University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Carl Gunter&fields=name,affiliations
# Elsa Gunter University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Elsa Gunter&fields=name,affiliations
# Indranil Gupta University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Indranil Gupta&fields=name,affiliations
# Saurabh Gupta University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Saurabh Gupta&fields=name,affiliations
# Jiawei Han University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Jiawei Han&fields=name,affiliations
# Mehdi T. Harandi University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Mehdi T. Harandi&fields=name,affiliations
# Sariel Har-Peled University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Sariel Har-Peled&fields=name,affiliations
# John C. Hart University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=John C. Hart&fields=name,affiliations
# Mark Hasegawa-Johnson University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Mark Hasegawa-Johnson&fields=name,affiliations
# Kris K. Hauser University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Kris K. Hauser&fields=name,affiliations
# Jing Rui He University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Jing Rui He&fields=name,affiliations
# Michael T. Heath University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael T. Heath&fields=name,affiliations
# Geoffrey Lindsay Herman University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Geoffrey Lindsay Herman&fields=name,affiliations
# Julia Constanze Hockenmaier University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Julia Constanze Hockenmaier&fields=name,affiliations
# Derek W. Hoiem University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Derek W. Hoiem&fields=name,affiliations
# Yih-Chun Hu University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Yih-Chun Hu&fields=name,affiliations
# Jian Huang University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Jian Huang&fields=name,affiliations
# Yun Huang University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Yun Huang&fields=name,affiliations
# Wen-mei Hwu University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Wen-mei Hwu&fields=name,affiliations
# Ravishankar K. Iyer University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Ravishankar K. Iyer&fields=name,affiliations
# Reyhaneh Jabbarvand University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Reyhaneh Jabbarvand&fields=name,affiliations
# Sheldon Howard Jacobson University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Sheldon Howard Jacobson&fields=name,affiliations
# Heng Ji University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Heng Ji&fields=name,affiliations
# Jing Jiang University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Jing Jiang&fields=name,affiliations
# Nan Jiang University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Nan Jiang&fields=name,affiliations
# Laxmikant V. Kale University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Laxmikant V. Kale&fields=name,affiliations
# Samuel N. Kamin University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Samuel N. Kamin&fields=name,affiliations
# Karrie Karahalios University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Karrie Karahalios&fields=name,affiliations
# Daniel S. Katz University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Daniel S. Katz&fields=name,affiliations
# T. Kesavadas University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=T. Kesavadas&fields=name,affiliations
# Dakshita Khurana University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Dakshita Khurana&fields=name,affiliations
# Nam Sung Kim University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Nam Sung Kim&fields=name,affiliations
# Volodymyr Kindratenko University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Volodymyr Kindratenko&fields=name,affiliations
# Alex Kirlik University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Alex Kirlik&fields=name,affiliations
# Andreas Paul Eberhard Kloeckner University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Andreas Paul Eberhard Kloeckner&fields=name,affiliations
# Sanmi Koyejo University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Sanmi Koyejo&fields=name,affiliations
# William T. Kramer University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=William T. Kramer&fields=name,affiliations
# Robin Hillary Kravets University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Robin Hillary Kravets&fields=name,affiliations
# David J. Kuck University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=David J. Kuck&fields=name,affiliations
# Rakesh Kumar University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Rakesh Kumar&fields=name,affiliations
# Ranjitha Kumar University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Ranjitha Kumar&fields=name,affiliations
# Steven M. LaValle University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Steven M. LaValle&fields=name,affiliations
# Duncan H. Lawrie University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Duncan H. Lawrie&fields=name,affiliations
# Svetlana Lazebnik University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Svetlana Lazebnik&fields=name,affiliations
# Kirill Levchenko University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Kirill Levchenko&fields=name,affiliations
# Colleen M. Lewis University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Colleen M. Lewis&fields=name,affiliations
# Bo Li University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Bo Li&fields=name,affiliations
# King C. Li University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=King C. Li&fields=name,affiliations
# C.L. David Liu University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=C.L. David Liu&fields=name,affiliations
# Hongye Liu University of illinois at Urbana Champaign
# https://api.semanticscholar.org/graph/v1/author/search?query=Hongye Liu&fields=name,affiliations
# Jane W.-S. Liu University of illinois at Urbana Champaign
# ...
# Georg Seelig University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Georg Seelig&fields=name,affiliations
# Steven Seitz University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Steven Seitz&fields=name,affiliations
# Linda Shapiro University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Linda Shapiro&fields=name,affiliations
# Joshua R. Smith University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Joshua R. Smith&fields=name,affiliations
# Noah Smith University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Noah Smith&fields=name,affiliations
# Siddhartha (Sidd) Srinivasa University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Siddhartha (Sidd) Srinivasa&fields=name,affiliations
# Dan Suciu University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Dan Suciu&fields=name,affiliations
# Steve Tanimoto University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Steve Tanimoto&fields=name,affiliations
# Zachary Tatlock University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Zachary Tatlock&fields=name,affiliations
# Michael Taylor University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Michael Taylor&fields=name,affiliations
# Stefano Tessaro University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Stefano Tessaro&fields=name,affiliations
# Christopher Thachuk University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Christopher Thachuk&fields=name,affiliations
# Emina Torlak University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Emina Torlak&fields=name,affiliations
# Sheng Wang University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Sheng Wang&fields=name,affiliations
# Xi Wang University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Xi Wang&fields=name,affiliations
# Yuliang Wang University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Yuliang Wang&fields=name,affiliations
# Robbie Weber University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Robbie Weber&fields=name,affiliations
# Daniel S. Weld University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Daniel S. Weld&fields=name,affiliations
# Brett Wortzman University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Brett Wortzman&fields=name,affiliations
# John Zahorjan University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=John Zahorjan&fields=name,affiliations
# Luke Zettlemoyer University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Luke Zettlemoyer&fields=name,affiliations
# Amy Zhang University of Washington
# https://api.semanticscholar.org/graph/v1/author/search?query=Amy Zhang&fields=name,affiliations
# Mo Abdallah Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mo Abdallah&fields=name,affiliations
# Arlon Adams Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Arlon Adams&fields=name,affiliations
# Marjory Baruch Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Marjory Baruch&fields=name,affiliations
# P. Berra Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=P. Berra&fields=name,affiliations
# Howard Blair Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Howard Blair&fields=name,affiliations
# Cynthia M. Bromka-Skafidas Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Cynthia M. Bromka-Skafidas&fields=name,affiliations
# Tomislav Bujanovic Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Tomislav Bujanovic&fields=name,affiliations
# Biao Chen Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Biao Chen&fields=name,affiliations
# C.Y. Roger Chen Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=C.Y. Roger Chen&fields=name,affiliations
# Shiu-Kai Chin Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Shiu-Kai Chin&fields=name,affiliations
# Wenliang (Kevin) Du Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Wenliang (Kevin) Du&fields=name,affiliations
# Sara Eftekharnejad Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Sara Eftekharnejad&fields=name,affiliations
# Ehat Ercanli Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ehat Ercanli&fields=name,affiliations
# Virgil Eveleigh Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Virgil Eveleigh&fields=name,affiliations
# Makan Fardad Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Makan Fardad&fields=name,affiliations
# Jim Fawcett Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jim Fawcett&fields=name,affiliations
# Ferdinando Fioretto Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ferdinando Fioretto&fields=name,affiliations
# Garth H. Foster Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Garth H. Foster&fields=name,affiliations
# Venkata S.S. Gandikota Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Venkata S.S. Gandikota&fields=name,affiliations
# Tammy Gharbi Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Tammy Gharbi&fields=name,affiliations
# Prasanta K. Ghosh Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Prasanta K. Ghosh&fields=name,affiliations
# Amrit L. Goel Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Amrit L. Goel&fields=name,affiliations
# Jennifer W. Graham Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jennifer W. Graham&fields=name,affiliations
# Mustafa Cenk Gursoy Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mustafa Cenk Gursoy&fields=name,affiliations
# Roger Harrington Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Roger Harrington&fields=name,affiliations
# Endadul Hoque Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Endadul Hoque&fields=name,affiliations
# Can Isik Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Can Isik&fields=name,affiliations
# Garrett Ethan Katz Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Garrett Ethan Katz&fields=name,affiliations
# Mehmet Kaya Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Mehmet Kaya&fields=name,affiliations
# Bryan S. Kim Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Bryan S. Kim&fields=name,affiliations
# Fanxin Kong Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Fanxin Kong&fields=name,affiliations
# Philipp Kornreich Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Philipp Kornreich&fields=name,affiliations
# Laura Lawson Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Laura Lawson&fields=name,affiliations
# Jay K. Lee Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jay K. Lee&fields=name,affiliations
# Andrew C. Lee Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Andrew C. Lee&fields=name,affiliations
# Ying Lin Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ying Lin&fields=name,affiliations
# Linda Lowe Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Linda Lowe&fields=name,affiliations
# Duane L. Marcy Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Duane L. Marcy&fields=name,affiliations
# Harold Mattson Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Harold Mattson&fields=name,affiliations
# Kishan Mehrotra Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Kishan Mehrotra&fields=name,affiliations
# Kristopher Micinski Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Kristopher Micinski&fields=name,affiliations
# Chilukuri K. Mohan Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Chilukuri K. Mohan&fields=name,affiliations
# F. Lockwood Morris Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=F. Lockwood Morris&fields=name,affiliations
# Rebecca Noble Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Rebecca Noble&fields=name,affiliations
# Jae C. Oh Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jae C. Oh&fields=name,affiliations
# Susan Older Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Susan Older&fields=name,affiliations
# Patanjali Parimi Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Patanjali Parimi&fields=name,affiliations
# Hakan P. Partal Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Hakan P. Partal&fields=name,affiliations
# Daniel J. Pease Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Daniel J. Pease&fields=name,affiliations
# Frederick W. Phelps Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Frederick W. Phelps&fields=name,affiliations
# Vir V. Phoha Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Vir V. Phoha&fields=name,affiliations
# Qinru Qiu Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Qinru Qiu&fields=name,affiliations
# Dana Radcliffe Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Dana Radcliffe&fields=name,affiliations
# Farzana Rahman Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Farzana Rahman&fields=name,affiliations
# John Robinson Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=John Robinson&fields=name,affiliations
# Martin Rothenberg Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Martin Rothenberg&fields=name,affiliations
# James S. Royer Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=James S. Royer&fields=name,affiliations
# Cynthia Salanger Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Cynthia Salanger&fields=name,affiliations
# Asif Salekin Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Asif Salekin&fields=name,affiliations
# Robert G. Sargent Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Robert G. Sargent&fields=name,affiliations
# Tapan Kumar Sarkar Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Tapan Kumar Sarkar&fields=name,affiliations
# Fritz H. Schlereth Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Fritz H. Schlereth&fields=name,affiliations
# Harry Schwarzlander Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Harry Schwarzlander&fields=name,affiliations
# Warren L. Semon Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Warren L. Semon&fields=name,affiliations
# Lixin Shen Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Lixin Shen&fields=name,affiliations
# Ernest Sibert Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Ernest Sibert&fields=name,affiliations
# Gurdip Singh Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Gurdip Singh&fields=name,affiliations
# J. Cole Smith Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=J. Cole Smith&fields=name,affiliations
# Zoey Smith Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Zoey Smith&fields=name,affiliations
# Qi Wang Song Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Qi Wang Song&fields=name,affiliations
# Sucheta Soundarajan Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Sucheta Soundarajan&fields=name,affiliations
# Edward P. Stabler Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Edward P. Stabler&fields=name,affiliations
# Edward F. Storm Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Edward F. Storm&fields=name,affiliations
# Bradley J. Strait Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Bradley J. Strait&fields=name,affiliations
# Jian Tang Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jian Tang&fields=name,affiliations
# Yuzhe (Richard) Tang Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Yuzhe (Richard) Tang&fields=name,affiliations
# William C. Tetley Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=William C. Tetley&fields=name,affiliations
# Pramod K. Varshney Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Pramod K. Varshney&fields=name,affiliations
# Senem Velipasalar Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Senem Velipasalar&fields=name,affiliations
# Joseph Waclawski Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Joseph Waclawski&fields=name,affiliations
# Li Wang Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Li Wang&fields=name,affiliations
# Donald Weiner Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Donald Weiner&fields=name,affiliations
# Jonathan S. Weissman Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Jonathan S. Weissman&fields=name,affiliations
# Edmund S. Yu Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Edmund S. Yu&fields=name,affiliations
# Reza Zafarani Syracuse University
# https://api.semanticscholar.org/graph/v1/author/search?query=Reza Zafarani&fields=name,affiliations
# Serdar Bozdag - Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Serdar Bozdag -&fields=name,affiliations
# Shion Guha Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Shion Guha&fields=name,affiliations
# Sheikh Iqbal Ahamed Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Sheikh Iqbal Ahamed&fields=name,affiliations
# Debbie Perouli Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Debbie Perouli&fields=name,affiliations
# Steven Goodman Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Steven Goodman&fields=name,affiliations
# Marquette - Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Marquette -&fields=name,affiliations
# Debbie Perouli and Shion Guha Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Debbie Perouli and Shion Guha&fields=name,affiliations
# CS Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=CS&fields=name,affiliations
# Shion Guha - Marquette University
# https://api.semanticscholar.org/graph/v1/author/search?query=Shion Guha -&fields=name,affiliations
# totally find: 5594
# find: 5133
# faculty with affiliation: 422

# %%
print("totally find: " + str(cnt_total))
print("find: " + str(cnt_find_name))
print("faculty with affiliation: " + str(cnt_find_institution))
# Out:
# totally find: 5594
# find: 5133
# faculty with affiliation: 422
